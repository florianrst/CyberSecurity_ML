# %%
import pandas as pd
import time
import plotly.graph_objects as go
import plotly.express as px

from pathlib import Path
from itertools import combinations
from plotly.subplots import make_subplots
from copy import deepcopy

from utils.data_processing import clean_data, load_data, processed_columns, full_dtypes

# %%
palette = px.colors.qualitative.Plotly

# %%
path=Path("./data")
if not path.joinpath("processed_data.csv").exists():
    clean_data(path.joinpath("cybersecurity_attacks.csv"))
dtypes = {col: col_type for col, col_type in full_dtypes.items() if col in processed_columns}
cleaned_data = load_data(path.joinpath("processed_data.csv"), dtype=dtypes)
# Out:
# Packet Length    int32
# dtype: object

# %%
relaunch = ""
while relaunch.lower() not in ["y","n"]:
    relaunch = input("Do you want to relaunch the analysis to find good combinations? (y/n) ")
if relaunch.lower() == "y":
    col_combinations = [col for col in cleaned_data.columns if col != "Attack Type"]
    col_combinations = list(combinations(col_combinations,3))

    nb_rows=cleaned_data.shape[0]
    good_combinations = []
    start_time = time.monotonic()
    for i,combination in enumerate(col_combinations):
        columns = [col for col in combination]+["Attack Type"]
        temp_data = cleaned_data[columns]
        temp_data = temp_data.pivot_table(
            index=combination,  
            columns="Attack Type",
            aggfunc="count",
            fill_value=0
        )
        temp_data["Total"]= temp_data.sum(axis=1)
        percentage_data = temp_data[["DDoS","Malware", "Intrusion"]].div(temp_data["Total"], axis=0)
        percentage_data = percentage_data.max(axis=1) - percentage_data.min(axis=1)
        stats = percentage_data.describe()
        if stats.loc["25%"] > 0.02 and stats.loc["75%"] < 0.99:
            print(f"Found good {combination}")
            output = [feature for feature in combination]
            output.extend([f"%.4f" % stats.loc[x] for x in stats.index])
            good_combinations.append(output)
        if i%100==0 and i!=0:
            print(f"Time since start for {i:d} combinations: {time.monotonic() - start_time:.2f} seconds")
    print(f"Total time: {time.monotonic() - start_time} seconds")
    good_combinations_df = pd.DataFrame(good_combinations, columns=["Feature 1", "Feature 2", "Feature 3", 'count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'])
    good_combinations_df.to_csv(path.joinpath("good_combinations.csv"), index=False)
else:
    good_combinations_df = pd.read_csv(path.joinpath("good_combinations.csv"))
# Out:
# Time since start for 100 combinations: 2.72 seconds
# Time since start for 200 combinations: 6.07 seconds
# Time since start for 300 combinations: 8.79 seconds
# Time since start for 400 combinations: 11.46 seconds
# Time since start for 500 combinations: 14.51 seconds
# Time since start for 600 combinations: 17.12 seconds
# Time since start for 700 combinations: 19.70 seconds
# Time since start for 800 combinations: 22.44 seconds
# Time since start for 900 combinations: 25.15 seconds
# Time since start for 1000 combinations: 27.62 seconds
# Time since start for 1100 combinations: 30.15 seconds
# Time since start for 1200 combinations: 32.67 seconds
# Time since start for 1300 combinations: 35.45 seconds
# Time since start for 1400 combinations: 38.08 seconds
# Time since start for 1500 combinations: 40.59 seconds
# Time since start for 1600 combinations: 43.30 seconds
# Time since start for 1700 combinations: 46.10 seconds
# Found good ('Protocol', 'Packet Type', 'Month')
# Found good ('Protocol', 'Packet Type', 'Day')
# Found good ('Protocol', 'Packet Type', 'Hour')
# Found good ('Protocol', 'Packet Type', 'Minute')
# Found good ('Protocol', 'Packet Type', 'Second')
# Found good ('Protocol', 'Packet Type', 'DayOfWeek')
# Found good ('Protocol', 'Packet Type', 'Browser Name')
# Found good ('Protocol', 'Packet Type', 'Browser Version')
# Found good ('Protocol', 'Packet Type', 'Browser Minor')
# Found good ('Protocol', 'Packet Type', 'Browser Patch')
# Found good ('Protocol', 'Packet Type', 'OS Version')
# Found good ('Protocol', 'Packet Type', 'OS Version Minor')
# Found good ('Protocol', 'Packet Type', 'OS Version Patch')
# Found good ('Protocol', 'Packet Type', 'Device Model')
# Found good ('Protocol', 'Packet Type', 'Device Type')
# Found good ('Protocol', 'Packet Type', 'Scale Packet Length')
# Time since start for 1800 combinations: 48.16 seconds
# Found good ('Protocol', 'Traffic Type', 'Month')
# Found good ('Protocol', 'Traffic Type', 'Day')
# Found good ('Protocol', 'Traffic Type', 'Hour')
# Found good ('Protocol', 'Traffic Type', 'Minute')
# Found good ('Protocol', 'Traffic Type', 'Second')
# Found good ('Protocol', 'Traffic Type', 'DayOfWeek')
# Found good ('Protocol', 'Traffic Type', 'Browser Name')
# Found good ('Protocol', 'Traffic Type', 'Browser Version')
# Found good ('Protocol', 'Traffic Type', 'Browser Minor')
# Found good ('Protocol', 'Traffic Type', 'Browser Patch')
# Found good ('Protocol', 'Traffic Type', 'OS Name')
# Found good ('Protocol', 'Traffic Type', 'OS Version')
# Found good ('Protocol', 'Traffic Type', 'OS Version Minor')
# Found good ('Protocol', 'Traffic Type', 'OS Version Patch')
# Found good ('Protocol', 'Traffic Type', 'Device Brand')
# Found good ('Protocol', 'Traffic Type', 'Device Model')
# Found good ('Protocol', 'Traffic Type', 'Device Type')
# Found good ('Protocol', 'Malware Indicators', 'Month')
# Found good ('Protocol', 'Malware Indicators', 'Day')
# Found good ('Protocol', 'Malware Indicators', 'Hour')
# Found good ('Protocol', 'Malware Indicators', 'Minute')
# Found good ('Protocol', 'Malware Indicators', 'Second')
# Found good ('Protocol', 'Malware Indicators', 'DayOfWeek')
# Found good ('Protocol', 'Malware Indicators', 'Browser Name')
# Found good ('Protocol', 'Malware Indicators', 'Browser Version')
# Found good ('Protocol', 'Malware Indicators', 'Browser Minor')
# Found good ('Protocol', 'Malware Indicators', 'Browser Patch')
# Found good ('Protocol', 'Malware Indicators', 'OS Version')
# Found good ('Protocol', 'Malware Indicators', 'OS Version Minor')
# Found good ('Protocol', 'Malware Indicators', 'OS Version Patch')
# Found good ('Protocol', 'Malware Indicators', 'Device Model')
# Found good ('Protocol', 'Malware Indicators', 'Device Type')
# Found good ('Protocol', 'Malware Indicators', 'Scale Packet Length')
# Time since start for 1900 combinations: 49.41 seconds
# Found good ('Protocol', 'Alerts/Warnings', 'Month')
# Found good ('Protocol', 'Alerts/Warnings', 'Day')
# Found good ('Protocol', 'Alerts/Warnings', 'Hour')
# Found good ('Protocol', 'Alerts/Warnings', 'Minute')
# Found good ('Protocol', 'Alerts/Warnings', 'Second')
# Found good ('Protocol', 'Alerts/Warnings', 'DayOfWeek')
# Found good ('Protocol', 'Alerts/Warnings', 'Browser Name')
# Found good ('Protocol', 'Alerts/Warnings', 'Browser Version')
# Found good ('Protocol', 'Alerts/Warnings', 'Browser Minor')
# Found good ('Protocol', 'Alerts/Warnings', 'Browser Patch')
# Found good ('Protocol', 'Alerts/Warnings', 'OS Version')
# Found good ('Protocol', 'Alerts/Warnings', 'OS Version Minor')
# Found good ('Protocol', 'Alerts/Warnings', 'OS Version Patch')
# Found good ('Protocol', 'Alerts/Warnings', 'Device Model')
# Found good ('Protocol', 'Alerts/Warnings', 'Device Type')
# Found good ('Protocol', 'Alerts/Warnings', 'Scale Packet Length')
# Found good ('Protocol', 'Attack Signature', 'Month')
# Found good ('Protocol', 'Attack Signature', 'Day')
# Found good ('Protocol', 'Attack Signature', 'Hour')
# Found good ('Protocol', 'Attack Signature', 'Minute')
# Found good ('Protocol', 'Attack Signature', 'Second')
# Found good ('Protocol', 'Attack Signature', 'Browser Name')
# Found good ('Protocol', 'Attack Signature', 'Browser Version')
# Found good ('Protocol', 'Attack Signature', 'Browser Minor')
# Found good ('Protocol', 'Attack Signature', 'Browser Patch')
# Found good ('Protocol', 'Attack Signature', 'OS Version')
# Found good ('Protocol', 'Attack Signature', 'OS Version Minor')
# Found good ('Protocol', 'Attack Signature', 'OS Version Patch')
# Found good ('Protocol', 'Attack Signature', 'Scale Packet Length')
# Found good ('Protocol', 'Action Taken', 'Month')
# Found good ('Protocol', 'Action Taken', 'Day')
# Found good ('Protocol', 'Action Taken', 'Hour')
# Found good ('Protocol', 'Action Taken', 'Minute')
# Found good ('Protocol', 'Action Taken', 'Second')
# Time since start for 2000 combinations: 50.60 seconds
# Found good ('Protocol', 'Action Taken', 'DayOfWeek')
# Found good ('Protocol', 'Action Taken', 'Browser Name')
# Found good ('Protocol', 'Action Taken', 'Browser Version')
# Found good ('Protocol', 'Action Taken', 'Browser Minor')
# Found good ('Protocol', 'Action Taken', 'Browser Patch')
# Found good ('Protocol', 'Action Taken', 'OS Name')
# Found good ('Protocol', 'Action Taken', 'OS Version')
# Found good ('Protocol', 'Action Taken', 'OS Version Minor')
# Found good ('Protocol', 'Action Taken', 'OS Version Patch')
# Found good ('Protocol', 'Action Taken', 'Device Brand')
# Found good ('Protocol', 'Action Taken', 'Device Model')
# Found good ('Protocol', 'Action Taken', 'Device Type')
# Found good ('Protocol', 'Action Taken', 'Scale Packet Length')
# Found good ('Protocol', 'Severity Level', 'Month')
# Found good ('Protocol', 'Severity Level', 'Day')
# Found good ('Protocol', 'Severity Level', 'Hour')
# Found good ('Protocol', 'Severity Level', 'Minute')
# Found good ('Protocol', 'Severity Level', 'Second')
# Found good ('Protocol', 'Severity Level', 'DayOfWeek')
# Found good ('Protocol', 'Severity Level', 'Browser Name')
# Found good ('Protocol', 'Severity Level', 'Browser Version')
# Found good ('Protocol', 'Severity Level', 'Browser Minor')
# Found good ('Protocol', 'Severity Level', 'Browser Patch')
# Found good ('Protocol', 'Severity Level', 'OS Name')
# Found good ('Protocol', 'Severity Level', 'OS Version')
# Found good ('Protocol', 'Severity Level', 'OS Version Minor')
# Found good ('Protocol', 'Severity Level', 'OS Version Patch')
# Found good ('Protocol', 'Severity Level', 'Device Model')
# Found good ('Protocol', 'Severity Level', 'Device Type')
# Found good ('Protocol', 'Network Segment', 'Year')
# Found good ('Protocol', 'Network Segment', 'Month')
# Found good ('Protocol', 'Network Segment', 'Day')
# Found good ('Protocol', 'Network Segment', 'Hour')
# Found good ('Protocol', 'Network Segment', 'Minute')
# Found good ('Protocol', 'Network Segment', 'Second')
# Found good ('Protocol', 'Network Segment', 'DayOfWeek')
# Found good ('Protocol', 'Network Segment', 'Browser Name')
# Found good ('Protocol', 'Network Segment', 'Browser Version')
# Found good ('Protocol', 'Network Segment', 'Browser Minor')
# Found good ('Protocol', 'Network Segment', 'Browser Patch')
# Found good ('Protocol', 'Network Segment', 'OS Version')
# Found good ('Protocol', 'Network Segment', 'OS Version Minor')
# Found good ('Protocol', 'Network Segment', 'OS Version Patch')
# Found good ('Protocol', 'Network Segment', 'Device Model')
# Found good ('Protocol', 'Network Segment', 'Device Type')
# Found good ('Protocol', 'Network Segment', 'Packet Bin')
# Time since start for 2100 combinations: 51.88 seconds
# Found good ('Protocol', 'Firewall Logs', 'Month')
# Found good ('Protocol', 'Firewall Logs', 'Day')
# Found good ('Protocol', 'Firewall Logs', 'Hour')
# Found good ('Protocol', 'Firewall Logs', 'Minute')
# Found good ('Protocol', 'Firewall Logs', 'Second')
# Found good ('Protocol', 'Firewall Logs', 'DayOfWeek')
# Found good ('Protocol', 'Firewall Logs', 'Browser Name')
# Found good ('Protocol', 'Firewall Logs', 'Browser Version')
# Found good ('Protocol', 'Firewall Logs', 'Browser Minor')
# Found good ('Protocol', 'Firewall Logs', 'Browser Patch')
# Found good ('Protocol', 'Firewall Logs', 'OS Version')
# Found good ('Protocol', 'Firewall Logs', 'OS Version Minor')
# Found good ('Protocol', 'Firewall Logs', 'OS Version Patch')
# Found good ('Protocol', 'Firewall Logs', 'Device Model')
# Found good ('Protocol', 'Firewall Logs', 'Device Type')
# Found good ('Protocol', 'Firewall Logs', 'Scale Packet Length')
# Found good ('Protocol', 'IDS/IPS Alerts', 'Month')
# Found good ('Protocol', 'IDS/IPS Alerts', 'Day')
# Found good ('Protocol', 'IDS/IPS Alerts', 'Hour')
# Found good ('Protocol', 'IDS/IPS Alerts', 'Minute')
# Found good ('Protocol', 'IDS/IPS Alerts', 'Second')
# Found good ('Protocol', 'IDS/IPS Alerts', 'Browser Name')
# Found good ('Protocol', 'IDS/IPS Alerts', 'Browser Version')
# Found good ('Protocol', 'IDS/IPS Alerts', 'Browser Minor')
# Found good ('Protocol', 'IDS/IPS Alerts', 'Browser Patch')
# Found good ('Protocol', 'IDS/IPS Alerts', 'OS Version')
# Found good ('Protocol', 'IDS/IPS Alerts', 'OS Version Minor')
# Found good ('Protocol', 'IDS/IPS Alerts', 'OS Version Patch')
# Found good ('Protocol', 'IDS/IPS Alerts', 'Device Model')
# Found good ('Protocol', 'IDS/IPS Alerts', 'Device Type')
# Found good ('Protocol', 'IDS/IPS Alerts', 'Scale Packet Length')
# Found good ('Protocol', 'Log Source', 'Month')
# Found good ('Protocol', 'Log Source', 'Day')
# Found good ('Protocol', 'Log Source', 'Hour')
# Found good ('Protocol', 'Log Source', 'Minute')
# Found good ('Protocol', 'Log Source', 'Second')
# Found good ('Protocol', 'Log Source', 'Browser Name')
# Found good ('Protocol', 'Log Source', 'Browser Version')
# Found good ('Protocol', 'Log Source', 'Browser Minor')
# Found good ('Protocol', 'Log Source', 'Browser Patch')
# Found good ('Protocol', 'Log Source', 'OS Version')
# Found good ('Protocol', 'Log Source', 'OS Version Minor')
# Found good ('Protocol', 'Log Source', 'OS Version Patch')
# Found good ('Protocol', 'Log Source', 'Device Model')
# Found good ('Protocol', 'Log Source', 'Device Type')
# Found good ('Protocol', 'Log Source', 'Scale Packet Length')
# Time since start for 2200 combinations: 53.34 seconds
# Found good ('Protocol', 'Year', 'Month')
# Found good ('Protocol', 'Year', 'Day')
# Found good ('Protocol', 'Year', 'Hour')
# Found good ('Protocol', 'Year', 'Minute')
# Found good ('Protocol', 'Year', 'Second')
# Found good ('Protocol', 'Year', 'DayOfWeek')
# Found good ('Protocol', 'Year', 'Browser Name')
# Found good ('Protocol', 'Year', 'Browser Version')
# Found good ('Protocol', 'Year', 'Browser Minor')
# Found good ('Protocol', 'Year', 'Browser Patch')
# Found good ('Protocol', 'Year', 'OS Name')
# Found good ('Protocol', 'Year', 'OS Version')
# Found good ('Protocol', 'Year', 'OS Version Minor')
# Found good ('Protocol', 'Year', 'OS Version Patch')
# Found good ('Protocol', 'Year', 'Device Model')
# Found good ('Protocol', 'Year', 'Device Type')
# Found good ('Protocol', 'Year', 'Packet Bin')
# Found good ('Protocol', 'Month', 'Day')
# Found good ('Protocol', 'Month', 'Hour')
# Found good ('Protocol', 'Month', 'Minute')
# Found good ('Protocol', 'Month', 'Second')
# Found good ('Protocol', 'Month', 'DayOfWeek')
# Found good ('Protocol', 'Month', 'IsWeekend')
# Found good ('Protocol', 'Month', 'Browser Name')
# Found good ('Protocol', 'Month', 'Browser Version')
# Found good ('Protocol', 'Month', 'Browser Patch Minor')
# Found good ('Protocol', 'Month', 'OS Name')
# Found good ('Protocol', 'Month', 'OS Version')
# Found good ('Protocol', 'Month', 'OS Version Minor')
# Found good ('Protocol', 'Month', 'OS Version Patch')
# Found good ('Protocol', 'Month', 'Device Brand')
# Found good ('Protocol', 'Month', 'Device Model')
# Found good ('Protocol', 'Month', 'Device Type')
# Found good ('Protocol', 'Month', 'Packet Bin')
# Found good ('Protocol', 'Month', 'Global Source IP')
# Found good ('Protocol', 'Month', 'Global Destination IP')
# Found good ('Protocol', 'Month', 'Is Proxy')
# Found good ('Protocol', 'Day', 'Hour')
# Found good ('Protocol', 'Day', 'Minute')
# Found good ('Protocol', 'Day', 'Second')
# Found good ('Protocol', 'Day', 'DayOfWeek')
# Found good ('Protocol', 'Day', 'IsWeekend')
# Found good ('Protocol', 'Day', 'Browser Name')
# Found good ('Protocol', 'Day', 'Browser Patch Minor')
# Found good ('Protocol', 'Day', 'OS Name')
# Found good ('Protocol', 'Day', 'OS Version')
# Found good ('Protocol', 'Day', 'OS Version Minor')
# Found good ('Protocol', 'Day', 'OS Version Patch')
# Found good ('Protocol', 'Day', 'OS Version Patch Minor')
# Found good ('Protocol', 'Day', 'Device Brand')
# Found good ('Protocol', 'Day', 'Device Model')
# Found good ('Protocol', 'Day', 'Device Type')
# Found good ('Protocol', 'Day', 'Packet Bin')
# Found good ('Protocol', 'Day', 'Global Source IP')
# Found good ('Protocol', 'Day', 'Global Destination IP')
# Found good ('Protocol', 'Day', 'Is Proxy')
# Found good ('Protocol', 'Hour', 'Minute')
# Found good ('Protocol', 'Hour', 'Second')
# Found good ('Protocol', 'Hour', 'DayOfWeek')
# Found good ('Protocol', 'Hour', 'IsWeekend')
# Found good ('Protocol', 'Hour', 'Browser Name')
# Found good ('Protocol', 'Hour', 'Browser Patch Minor')
# Found good ('Protocol', 'Hour', 'OS Name')
# Found good ('Protocol', 'Hour', 'OS Version')
# Found good ('Protocol', 'Hour', 'OS Version Minor')
# Found good ('Protocol', 'Hour', 'OS Version Patch')
# Found good ('Protocol', 'Hour', 'OS Version Patch Minor')
# Found good ('Protocol', 'Hour', 'Device Brand')
# Found good ('Protocol', 'Hour', 'Device Model')
# Found good ('Protocol', 'Hour', 'Device Type')
# Time since start for 2300 combinations: 54.40 seconds
# Found good ('Protocol', 'Hour', 'Packet Bin')
# Found good ('Protocol', 'Hour', 'Global Source IP')
# Found good ('Protocol', 'Hour', 'Global Destination IP')
# Found good ('Protocol', 'Hour', 'Is Proxy')
# Found good ('Protocol', 'Minute', 'Second')
# Found good ('Protocol', 'Minute', 'DayOfWeek')
# Found good ('Protocol', 'Minute', 'IsWeekend')
# Found good ('Protocol', 'Minute', 'Browser Name')
# Found good ('Protocol', 'Minute', 'Browser Patch Minor')
# Found good ('Protocol', 'Minute', 'OS Name')
# Found good ('Protocol', 'Minute', 'OS Version')
# Found good ('Protocol', 'Minute', 'OS Version Minor')
# Found good ('Protocol', 'Minute', 'OS Version Patch')
# Found good ('Protocol', 'Minute', 'OS Version Patch Minor')
# Found good ('Protocol', 'Minute', 'Device Brand')
# Found good ('Protocol', 'Minute', 'Device Model')
# Found good ('Protocol', 'Minute', 'Device Type')
# Found good ('Protocol', 'Minute', 'Packet Bin')
# Found good ('Protocol', 'Minute', 'Is Proxy')
# Found good ('Protocol', 'Second', 'DayOfWeek')
# Found good ('Protocol', 'Second', 'IsWeekend')
# Found good ('Protocol', 'Second', 'Browser Name')
# Found good ('Protocol', 'Second', 'Browser Patch Minor')
# Found good ('Protocol', 'Second', 'OS Name')
# Found good ('Protocol', 'Second', 'OS Version')
# Found good ('Protocol', 'Second', 'OS Version Minor')
# Found good ('Protocol', 'Second', 'OS Version Patch')
# Found good ('Protocol', 'Second', 'OS Version Patch Minor')
# Found good ('Protocol', 'Second', 'Device Brand')
# Found good ('Protocol', 'Second', 'Device Model')
# Found good ('Protocol', 'Second', 'Device Type')
# Found good ('Protocol', 'Second', 'Packet Bin')
# Found good ('Protocol', 'Second', 'Global Source IP')
# Found good ('Protocol', 'Second', 'Is Proxy')
# Found good ('Protocol', 'DayOfWeek', 'Browser Name')
# Found good ('Protocol', 'DayOfWeek', 'Browser Version')
# Found good ('Protocol', 'DayOfWeek', 'Browser Minor')
# Found good ('Protocol', 'DayOfWeek', 'Browser Patch')
# Found good ('Protocol', 'DayOfWeek', 'OS Name')
# Found good ('Protocol', 'DayOfWeek', 'OS Version')
# Found good ('Protocol', 'DayOfWeek', 'OS Version Minor')
# Found good ('Protocol', 'DayOfWeek', 'OS Version Patch')
# Found good ('Protocol', 'DayOfWeek', 'Device Brand')
# Found good ('Protocol', 'DayOfWeek', 'Device Model')
# Found good ('Protocol', 'DayOfWeek', 'Device Type')
# Found good ('Protocol', 'DayOfWeek', 'Packet Bin')
# Found good ('Protocol', 'IsWeekend', 'Browser Name')
# Found good ('Protocol', 'IsWeekend', 'Browser Version')
# Found good ('Protocol', 'IsWeekend', 'Browser Minor')
# Found good ('Protocol', 'IsWeekend', 'Browser Patch')
# Found good ('Protocol', 'IsWeekend', 'OS Version')
# Found good ('Protocol', 'IsWeekend', 'OS Version Minor')
# Found good ('Protocol', 'IsWeekend', 'OS Version Patch')
# Found good ('Protocol', 'IsWeekend', 'Device Model')
# Found good ('Protocol', 'IsWeekend', 'Device Type')
# Found good ('Protocol', 'IsWeekend', 'Scale Packet Length')
# Found good ('Protocol', 'Browser Name', 'Browser Version')
# Found good ('Protocol', 'Browser Name', 'Browser Minor')
# Found good ('Protocol', 'Browser Name', 'Browser Patch')
# Found good ('Protocol', 'Browser Name', 'Browser Patch Minor')
# Found good ('Protocol', 'Browser Name', 'OS Name')
# Found good ('Protocol', 'Browser Name', 'OS Version')
# Found good ('Protocol', 'Browser Name', 'OS Version Minor')
# Time since start for 2400 combinations: 55.56 seconds
# Found good ('Protocol', 'Browser Name', 'OS Version Patch')
# Found good ('Protocol', 'Browser Name', 'OS Version Patch Minor')
# Found good ('Protocol', 'Browser Name', 'Device Brand')
# Found good ('Protocol', 'Browser Name', 'Device Model')
# Found good ('Protocol', 'Browser Name', 'Device Type')
# Found good ('Protocol', 'Browser Name', 'Packet Bin')
# Found good ('Protocol', 'Browser Name', 'Global Source IP')
# Found good ('Protocol', 'Browser Name', 'Global Destination IP')
# Found good ('Protocol', 'Browser Name', 'Is Proxy')
# Found good ('Protocol', 'Browser Version', 'Browser Minor')
# Found good ('Protocol', 'Browser Version', 'Browser Patch Minor')
# Found good ('Protocol', 'Browser Version', 'OS Name')
# Found good ('Protocol', 'Browser Version', 'OS Version Patch Minor')
# Found good ('Protocol', 'Browser Version', 'Device Brand')
# Found good ('Protocol', 'Browser Version', 'Device Model')
# Found good ('Protocol', 'Browser Version', 'Device Type')
# Found good ('Protocol', 'Browser Version', 'Packet Bin')
# Found good ('Protocol', 'Browser Version', 'Global Source IP')
# Found good ('Protocol', 'Browser Version', 'Global Destination IP')
# Found good ('Protocol', 'Browser Version', 'Is Proxy')
# Found good ('Protocol', 'Browser Minor', 'Browser Patch')
# Found good ('Protocol', 'Browser Minor', 'Browser Patch Minor')
# Found good ('Protocol', 'Browser Minor', 'OS Name')
# Found good ('Protocol', 'Browser Minor', 'OS Version Minor')
# Found good ('Protocol', 'Browser Minor', 'OS Version Patch')
# Found good ('Protocol', 'Browser Minor', 'OS Version Patch Minor')
# Found good ('Protocol', 'Browser Minor', 'Packet Bin')
# Found good ('Protocol', 'Browser Minor', 'Global Source IP')
# Found good ('Protocol', 'Browser Minor', 'Global Destination IP')
# Found good ('Protocol', 'Browser Minor', 'Is Proxy')
# Found good ('Protocol', 'Browser Patch', 'Browser Patch Minor')
# Found good ('Protocol', 'Browser Patch', 'OS Name')
# Found good ('Protocol', 'Browser Patch', 'OS Version Patch Minor')
# Found good ('Protocol', 'Browser Patch', 'Device Brand')
# Found good ('Protocol', 'Browser Patch', 'Device Model')
# Found good ('Protocol', 'Browser Patch', 'Device Type')
# Found good ('Protocol', 'Browser Patch', 'Packet Bin')
# Found good ('Protocol', 'Browser Patch', 'Global Source IP')
# Found good ('Protocol', 'Browser Patch', 'Global Destination IP')
# Found good ('Protocol', 'Browser Patch', 'Is Proxy')
# Found good ('Protocol', 'Browser Patch Minor', 'OS Version')
# Found good ('Protocol', 'Browser Patch Minor', 'OS Version Minor')
# Found good ('Protocol', 'Browser Patch Minor', 'OS Version Patch')
# Found good ('Protocol', 'Browser Patch Minor', 'Device Model')
# Found good ('Protocol', 'Browser Patch Minor', 'Device Type')
# Found good ('Protocol', 'Browser Patch Minor', 'Scale Packet Length')
# Found good ('Protocol', 'OS Name', 'OS Version')
# Found good ('Protocol', 'OS Name', 'OS Version Minor')
# Found good ('Protocol', 'OS Name', 'OS Version Patch')
# Found good ('Protocol', 'OS Name', 'Is Proxy')
# Found good ('Protocol', 'OS Version', 'OS Version Minor')
# Found good ('Protocol', 'OS Version', 'OS Version Patch')
# Found good ('Protocol', 'OS Version', 'OS Version Patch Minor')
# Found good ('Protocol', 'OS Version', 'Device Brand')
# Found good ('Protocol', 'OS Version', 'Device Model')
# Found good ('Protocol', 'OS Version', 'Device Type')
# Found good ('Protocol', 'OS Version', 'Packet Bin')
# Time since start for 2500 combinations: 56.95 seconds
# Found good ('Protocol', 'OS Version', 'Global Source IP')
# Found good ('Protocol', 'OS Version', 'Global Destination IP')
# Found good ('Protocol', 'OS Version', 'Is Proxy')
# Found good ('Protocol', 'OS Version Minor', 'OS Version Patch')
# Found good ('Protocol', 'OS Version Minor', 'OS Version Patch Minor')
# Found good ('Protocol', 'OS Version Minor', 'Device Brand')
# Found good ('Protocol', 'OS Version Minor', 'Device Model')
# Found good ('Protocol', 'OS Version Minor', 'Device Type')
# Found good ('Protocol', 'OS Version Minor', 'Packet Bin')
# Found good ('Protocol', 'OS Version Minor', 'Global Source IP')
# Found good ('Protocol', 'OS Version Minor', 'Global Destination IP')
# Found good ('Protocol', 'OS Version Minor', 'Is Proxy')
# Found good ('Protocol', 'OS Version Patch', 'OS Version Patch Minor')
# Found good ('Protocol', 'OS Version Patch', 'Device Brand')
# Found good ('Protocol', 'OS Version Patch', 'Device Model')
# Found good ('Protocol', 'OS Version Patch', 'Device Type')
# Found good ('Protocol', 'OS Version Patch', 'Packet Bin')
# Found good ('Protocol', 'OS Version Patch', 'Global Source IP')
# Found good ('Protocol', 'OS Version Patch', 'Global Destination IP')
# Found good ('Protocol', 'OS Version Patch', 'Is Proxy')
# Found good ('Protocol', 'OS Version Patch Minor', 'Scale Packet Length')
# Found good ('Protocol', 'Device Brand', 'Packet Bin')
# Found good ('Protocol', 'Device Model', 'Packet Bin')
# Found good ('Protocol', 'Device Model', 'Global Destination IP')
# Found good ('Protocol', 'Device Model', 'Is Proxy')
# Found good ('Protocol', 'Device Type', 'Packet Bin')
# Found good ('Protocol', 'Device Type', 'Global Destination IP')
# Found good ('Protocol', 'Device Type', 'Is Proxy')
# Found good ('Protocol', 'Packet Bin', 'Scale Packet Length')
# Found good ('Protocol', 'Scale Packet Length', 'Global Source IP')
# Found good ('Protocol', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Protocol', 'Scale Packet Length', 'Is Proxy')
# Found good ('Packet Type', 'Traffic Type', 'Month')
# Found good ('Packet Type', 'Traffic Type', 'Day')
# Found good ('Packet Type', 'Traffic Type', 'Hour')
# Found good ('Packet Type', 'Traffic Type', 'Minute')
# Found good ('Packet Type', 'Traffic Type', 'Second')
# Time since start for 2600 combinations: 58.40 seconds
# Found good ('Packet Type', 'Traffic Type', 'DayOfWeek')
# Found good ('Packet Type', 'Traffic Type', 'Browser Name')
# Found good ('Packet Type', 'Traffic Type', 'Browser Version')
# Found good ('Packet Type', 'Traffic Type', 'Browser Minor')
# Found good ('Packet Type', 'Traffic Type', 'Browser Patch')
# Found good ('Packet Type', 'Traffic Type', 'OS Version')
# Found good ('Packet Type', 'Traffic Type', 'OS Version Minor')
# Found good ('Packet Type', 'Traffic Type', 'OS Version Patch')
# Found good ('Packet Type', 'Traffic Type', 'Device Model')
# Found good ('Packet Type', 'Traffic Type', 'Device Type')
# Found good ('Packet Type', 'Traffic Type', 'Scale Packet Length')
# Found good ('Packet Type', 'Malware Indicators', 'Day')
# Found good ('Packet Type', 'Malware Indicators', 'Hour')
# Found good ('Packet Type', 'Malware Indicators', 'Minute')
# Found good ('Packet Type', 'Malware Indicators', 'Second')
# Found good ('Packet Type', 'Malware Indicators', 'Browser Name')
# Found good ('Packet Type', 'Malware Indicators', 'Browser Version')
# Found good ('Packet Type', 'Malware Indicators', 'Browser Minor')
# Found good ('Packet Type', 'Malware Indicators', 'Browser Patch')
# Found good ('Packet Type', 'Malware Indicators', 'OS Version')
# Found good ('Packet Type', 'Malware Indicators', 'OS Version Minor')
# Found good ('Packet Type', 'Malware Indicators', 'OS Version Patch')
# Found good ('Packet Type', 'Malware Indicators', 'Device Model')
# Found good ('Packet Type', 'Malware Indicators', 'Device Type')
# Found good ('Packet Type', 'Malware Indicators', 'Scale Packet Length')
# Time since start for 2700 combinations: 59.81 seconds
# Found good ('Packet Type', 'Alerts/Warnings', 'Day')
# Found good ('Packet Type', 'Alerts/Warnings', 'Hour')
# Found good ('Packet Type', 'Alerts/Warnings', 'Minute')
# Found good ('Packet Type', 'Alerts/Warnings', 'Second')
# Found good ('Packet Type', 'Alerts/Warnings', 'Browser Name')
# Found good ('Packet Type', 'Alerts/Warnings', 'Browser Version')
# Found good ('Packet Type', 'Alerts/Warnings', 'Browser Minor')
# Found good ('Packet Type', 'Alerts/Warnings', 'Browser Patch')
# Found good ('Packet Type', 'Alerts/Warnings', 'OS Version')
# Found good ('Packet Type', 'Alerts/Warnings', 'OS Version Minor')
# Found good ('Packet Type', 'Alerts/Warnings', 'OS Version Patch')
# Found good ('Packet Type', 'Alerts/Warnings', 'Device Model')
# Found good ('Packet Type', 'Alerts/Warnings', 'Device Type')
# Found good ('Packet Type', 'Alerts/Warnings', 'Scale Packet Length')
# Found good ('Packet Type', 'Attack Signature', 'Month')
# Found good ('Packet Type', 'Attack Signature', 'Day')
# Found good ('Packet Type', 'Attack Signature', 'Hour')
# Found good ('Packet Type', 'Attack Signature', 'Minute')
# Found good ('Packet Type', 'Attack Signature', 'Second')
# Found good ('Packet Type', 'Attack Signature', 'Browser Name')
# Found good ('Packet Type', 'Attack Signature', 'Browser Version')
# Found good ('Packet Type', 'Attack Signature', 'Browser Minor')
# Found good ('Packet Type', 'Attack Signature', 'Browser Patch')
# Found good ('Packet Type', 'Attack Signature', 'OS Version')
# Found good ('Packet Type', 'Attack Signature', 'OS Version Minor')
# Found good ('Packet Type', 'Attack Signature', 'OS Version Patch')
# Found good ('Packet Type', 'Attack Signature', 'Device Model')
# Found good ('Packet Type', 'Attack Signature', 'Device Type')
# Found good ('Packet Type', 'Attack Signature', 'Packet Bin')
# Found good ('Packet Type', 'Attack Signature', 'Scale Packet Length')
# Found good ('Packet Type', 'Action Taken', 'Month')
# Found good ('Packet Type', 'Action Taken', 'Day')
# Found good ('Packet Type', 'Action Taken', 'Hour')
# Found good ('Packet Type', 'Action Taken', 'Minute')
# Found good ('Packet Type', 'Action Taken', 'Second')
# Found good ('Packet Type', 'Action Taken', 'Browser Name')
# Found good ('Packet Type', 'Action Taken', 'Browser Version')
# Found good ('Packet Type', 'Action Taken', 'Browser Minor')
# Found good ('Packet Type', 'Action Taken', 'Browser Patch')
# Found good ('Packet Type', 'Action Taken', 'OS Version')
# Found good ('Packet Type', 'Action Taken', 'OS Version Minor')
# Found good ('Packet Type', 'Action Taken', 'OS Version Patch')
# Found good ('Packet Type', 'Action Taken', 'Device Model')
# Found good ('Packet Type', 'Action Taken', 'Device Type')
# Found good ('Packet Type', 'Action Taken', 'Scale Packet Length')
# Time since start for 2800 combinations: 60.80 seconds
# Found good ('Packet Type', 'Severity Level', 'Month')
# Found good ('Packet Type', 'Severity Level', 'Day')
# Found good ('Packet Type', 'Severity Level', 'Hour')
# Found good ('Packet Type', 'Severity Level', 'Minute')
# Found good ('Packet Type', 'Severity Level', 'Second')
# Found good ('Packet Type', 'Severity Level', 'DayOfWeek')
# Found good ('Packet Type', 'Severity Level', 'Browser Name')
# Found good ('Packet Type', 'Severity Level', 'Browser Version')
# Found good ('Packet Type', 'Severity Level', 'Browser Minor')
# Found good ('Packet Type', 'Severity Level', 'Browser Patch')
# Found good ('Packet Type', 'Severity Level', 'OS Version')
# Found good ('Packet Type', 'Severity Level', 'OS Version Minor')
# Found good ('Packet Type', 'Severity Level', 'OS Version Patch')
# Found good ('Packet Type', 'Severity Level', 'Device Model')
# Found good ('Packet Type', 'Severity Level', 'Device Type')
# Found good ('Packet Type', 'Severity Level', 'Scale Packet Length')
# Found good ('Packet Type', 'Network Segment', 'Month')
# Found good ('Packet Type', 'Network Segment', 'Day')
# Found good ('Packet Type', 'Network Segment', 'Hour')
# Found good ('Packet Type', 'Network Segment', 'Minute')
# Found good ('Packet Type', 'Network Segment', 'Second')
# Found good ('Packet Type', 'Network Segment', 'DayOfWeek')
# Found good ('Packet Type', 'Network Segment', 'Browser Name')
# Found good ('Packet Type', 'Network Segment', 'Browser Version')
# Found good ('Packet Type', 'Network Segment', 'Browser Minor')
# Found good ('Packet Type', 'Network Segment', 'Browser Patch')
# Found good ('Packet Type', 'Network Segment', 'OS Version')
# Found good ('Packet Type', 'Network Segment', 'OS Version Minor')
# Found good ('Packet Type', 'Network Segment', 'OS Version Patch')
# Found good ('Packet Type', 'Network Segment', 'Device Brand')
# Found good ('Packet Type', 'Network Segment', 'Device Model')
# Found good ('Packet Type', 'Network Segment', 'Device Type')
# Found good ('Packet Type', 'Network Segment', 'Scale Packet Length')
# Time since start for 2900 combinations: 62.35 seconds
# Found good ('Packet Type', 'Firewall Logs', 'Month')
# Found good ('Packet Type', 'Firewall Logs', 'Day')
# Found good ('Packet Type', 'Firewall Logs', 'Hour')
# Found good ('Packet Type', 'Firewall Logs', 'Minute')
# Found good ('Packet Type', 'Firewall Logs', 'Second')
# Found good ('Packet Type', 'Firewall Logs', 'Browser Version')
# Found good ('Packet Type', 'Firewall Logs', 'Browser Minor')
# Found good ('Packet Type', 'Firewall Logs', 'Browser Patch')
# Found good ('Packet Type', 'Firewall Logs', 'OS Version')
# Found good ('Packet Type', 'Firewall Logs', 'OS Version Minor')
# Found good ('Packet Type', 'Firewall Logs', 'OS Version Patch')
# Found good ('Packet Type', 'Firewall Logs', 'Device Model')
# Found good ('Packet Type', 'Firewall Logs', 'Device Type')
# Found good ('Packet Type', 'Firewall Logs', 'Scale Packet Length')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'Month')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'Day')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'Hour')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'Minute')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'Second')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'Browser Name')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'Browser Version')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'Browser Minor')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'Browser Patch')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'OS Version')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'OS Version Minor')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'OS Version Patch')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'Device Model')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'Device Type')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'Scale Packet Length')
# Found good ('Packet Type', 'Log Source', 'Month')
# Found good ('Packet Type', 'Log Source', 'Day')
# Found good ('Packet Type', 'Log Source', 'Hour')
# Found good ('Packet Type', 'Log Source', 'Minute')
# Found good ('Packet Type', 'Log Source', 'Second')
# Found good ('Packet Type', 'Log Source', 'Browser Name')
# Found good ('Packet Type', 'Log Source', 'Browser Version')
# Found good ('Packet Type', 'Log Source', 'Browser Minor')
# Found good ('Packet Type', 'Log Source', 'Browser Patch')
# Found good ('Packet Type', 'Log Source', 'OS Version')
# Found good ('Packet Type', 'Log Source', 'OS Version Minor')
# Found good ('Packet Type', 'Log Source', 'OS Version Patch')
# Found good ('Packet Type', 'Log Source', 'Device Model')
# Found good ('Packet Type', 'Log Source', 'Device Type')
# Found good ('Packet Type', 'Log Source', 'Scale Packet Length')
# Found good ('Packet Type', 'Year', 'Month')
# Found good ('Packet Type', 'Year', 'Day')
# Found good ('Packet Type', 'Year', 'Hour')
# Found good ('Packet Type', 'Year', 'Minute')
# Found good ('Packet Type', 'Year', 'Second')
# Found good ('Packet Type', 'Year', 'DayOfWeek')
# Found good ('Packet Type', 'Year', 'Browser Name')
# Found good ('Packet Type', 'Year', 'Browser Version')
# Found good ('Packet Type', 'Year', 'Browser Minor')
# Found good ('Packet Type', 'Year', 'Browser Patch')
# Found good ('Packet Type', 'Year', 'OS Name')
# Found good ('Packet Type', 'Year', 'OS Version')
# Found good ('Packet Type', 'Year', 'OS Version Minor')
# Time since start for 3000 combinations: 63.45 seconds
# Found good ('Packet Type', 'Year', 'OS Version Patch')
# Found good ('Packet Type', 'Year', 'Device Model')
# Found good ('Packet Type', 'Year', 'Device Type')
# Found good ('Packet Type', 'Year', 'Scale Packet Length')
# Found good ('Packet Type', 'Month', 'Day')
# Found good ('Packet Type', 'Month', 'Hour')
# Found good ('Packet Type', 'Month', 'Minute')
# Found good ('Packet Type', 'Month', 'Second')
# Found good ('Packet Type', 'Month', 'DayOfWeek')
# Found good ('Packet Type', 'Month', 'IsWeekend')
# Found good ('Packet Type', 'Month', 'Browser Name')
# Found good ('Packet Type', 'Month', 'Browser Version')
# Found good ('Packet Type', 'Month', 'Browser Minor')
# Found good ('Packet Type', 'Month', 'Browser Patch')
# Found good ('Packet Type', 'Month', 'Browser Patch Minor')
# Found good ('Packet Type', 'Month', 'OS Name')
# Found good ('Packet Type', 'Month', 'OS Version')
# Found good ('Packet Type', 'Month', 'OS Version Minor')
# Found good ('Packet Type', 'Month', 'OS Version Patch')
# Found good ('Packet Type', 'Month', 'Device Brand')
# Found good ('Packet Type', 'Month', 'Device Model')
# Found good ('Packet Type', 'Month', 'Device Type')
# Found good ('Packet Type', 'Month', 'Packet Bin')
# Found good ('Packet Type', 'Month', 'Global Source IP')
# Found good ('Packet Type', 'Month', 'Global Destination IP')
# Found good ('Packet Type', 'Month', 'Is Proxy')
# Found good ('Packet Type', 'Day', 'Hour')
# Found good ('Packet Type', 'Day', 'Minute')
# Found good ('Packet Type', 'Day', 'Second')
# Found good ('Packet Type', 'Day', 'DayOfWeek')
# Found good ('Packet Type', 'Day', 'IsWeekend')
# Found good ('Packet Type', 'Day', 'Browser Name')
# Found good ('Packet Type', 'Day', 'Browser Version')
# Found good ('Packet Type', 'Day', 'Browser Patch Minor')
# Found good ('Packet Type', 'Day', 'OS Name')
# Found good ('Packet Type', 'Day', 'OS Version')
# Found good ('Packet Type', 'Day', 'OS Version Minor')
# Found good ('Packet Type', 'Day', 'OS Version Patch')
# Found good ('Packet Type', 'Day', 'OS Version Patch Minor')
# Found good ('Packet Type', 'Day', 'Device Brand')
# Found good ('Packet Type', 'Day', 'Device Model')
# Found good ('Packet Type', 'Day', 'Device Type')
# Found good ('Packet Type', 'Day', 'Packet Bin')
# Found good ('Packet Type', 'Day', 'Global Source IP')
# Found good ('Packet Type', 'Day', 'Global Destination IP')
# Found good ('Packet Type', 'Day', 'Is Proxy')
# Found good ('Packet Type', 'Hour', 'Minute')
# Found good ('Packet Type', 'Hour', 'Second')
# Found good ('Packet Type', 'Hour', 'DayOfWeek')
# Found good ('Packet Type', 'Hour', 'IsWeekend')
# Found good ('Packet Type', 'Hour', 'Browser Name')
# Found good ('Packet Type', 'Hour', 'Browser Version')
# Found good ('Packet Type', 'Hour', 'Browser Patch Minor')
# Found good ('Packet Type', 'Hour', 'OS Name')
# Found good ('Packet Type', 'Hour', 'OS Version')
# Found good ('Packet Type', 'Hour', 'OS Version Minor')
# Found good ('Packet Type', 'Hour', 'OS Version Patch')
# Found good ('Packet Type', 'Hour', 'Device Brand')
# Found good ('Packet Type', 'Hour', 'Device Model')
# Found good ('Packet Type', 'Hour', 'Device Type')
# Found good ('Packet Type', 'Hour', 'Packet Bin')
# Found good ('Packet Type', 'Hour', 'Global Source IP')
# Found good ('Packet Type', 'Hour', 'Is Proxy')
# Found good ('Packet Type', 'Minute', 'Second')
# Found good ('Packet Type', 'Minute', 'DayOfWeek')
# Found good ('Packet Type', 'Minute', 'IsWeekend')
# Found good ('Packet Type', 'Minute', 'Browser Name')
# Found good ('Packet Type', 'Minute', 'Browser Patch Minor')
# Found good ('Packet Type', 'Minute', 'OS Name')
# Found good ('Packet Type', 'Minute', 'OS Version')
# Found good ('Packet Type', 'Minute', 'OS Version Minor')
# Found good ('Packet Type', 'Minute', 'OS Version Patch')
# Found good ('Packet Type', 'Minute', 'OS Version Patch Minor')
# Time since start for 3100 combinations: 64.51 seconds
# Found good ('Packet Type', 'Minute', 'Device Brand')
# Found good ('Packet Type', 'Minute', 'Device Model')
# Found good ('Packet Type', 'Minute', 'Device Type')
# Found good ('Packet Type', 'Minute', 'Packet Bin')
# Found good ('Packet Type', 'Minute', 'Global Source IP')
# Found good ('Packet Type', 'Minute', 'Is Proxy')
# Found good ('Packet Type', 'Second', 'DayOfWeek')
# Found good ('Packet Type', 'Second', 'IsWeekend')
# Found good ('Packet Type', 'Second', 'Browser Name')
# Found good ('Packet Type', 'Second', 'Browser Patch Minor')
# Found good ('Packet Type', 'Second', 'OS Name')
# Found good ('Packet Type', 'Second', 'OS Version')
# Found good ('Packet Type', 'Second', 'OS Version Minor')
# Found good ('Packet Type', 'Second', 'OS Version Patch')
# Found good ('Packet Type', 'Second', 'OS Version Patch Minor')
# Found good ('Packet Type', 'Second', 'Device Brand')
# Found good ('Packet Type', 'Second', 'Device Model')
# Found good ('Packet Type', 'Second', 'Device Type')
# Found good ('Packet Type', 'Second', 'Packet Bin')
# Found good ('Packet Type', 'Second', 'Global Source IP')
# Found good ('Packet Type', 'Second', 'Global Destination IP')
# Found good ('Packet Type', 'Second', 'Is Proxy')
# Found good ('Packet Type', 'DayOfWeek', 'Browser Name')
# Found good ('Packet Type', 'DayOfWeek', 'Browser Version')
# Found good ('Packet Type', 'DayOfWeek', 'Browser Minor')
# Found good ('Packet Type', 'DayOfWeek', 'Browser Patch')
# Found good ('Packet Type', 'DayOfWeek', 'OS Name')
# Found good ('Packet Type', 'DayOfWeek', 'OS Version')
# Found good ('Packet Type', 'DayOfWeek', 'OS Version Minor')
# Found good ('Packet Type', 'DayOfWeek', 'OS Version Patch')
# Found good ('Packet Type', 'DayOfWeek', 'Device Brand')
# Found good ('Packet Type', 'DayOfWeek', 'Device Model')
# Found good ('Packet Type', 'DayOfWeek', 'Device Type')
# Found good ('Packet Type', 'DayOfWeek', 'Packet Bin')
# Found good ('Packet Type', 'IsWeekend', 'Browser Name')
# Found good ('Packet Type', 'IsWeekend', 'Browser Version')
# Found good ('Packet Type', 'IsWeekend', 'Browser Minor')
# Found good ('Packet Type', 'IsWeekend', 'Browser Patch')
# Found good ('Packet Type', 'IsWeekend', 'OS Version')
# Found good ('Packet Type', 'IsWeekend', 'OS Version Minor')
# Found good ('Packet Type', 'IsWeekend', 'OS Version Patch')
# Found good ('Packet Type', 'IsWeekend', 'Device Model')
# Found good ('Packet Type', 'IsWeekend', 'Device Type')
# Found good ('Packet Type', 'IsWeekend', 'Scale Packet Length')
# Found good ('Packet Type', 'Browser Name', 'Browser Version')
# Found good ('Packet Type', 'Browser Name', 'Browser Minor')
# Found good ('Packet Type', 'Browser Name', 'Browser Patch')
# Found good ('Packet Type', 'Browser Name', 'Browser Patch Minor')
# Found good ('Packet Type', 'Browser Name', 'OS Name')
# Found good ('Packet Type', 'Browser Name', 'OS Version')
# Found good ('Packet Type', 'Browser Name', 'OS Version Minor')
# Found good ('Packet Type', 'Browser Name', 'OS Version Patch')
# Found good ('Packet Type', 'Browser Name', 'OS Version Patch Minor')
# Found good ('Packet Type', 'Browser Name', 'Device Brand')
# Found good ('Packet Type', 'Browser Name', 'Device Model')
# Found good ('Packet Type', 'Browser Name', 'Device Type')
# Found good ('Packet Type', 'Browser Name', 'Packet Bin')
# Found good ('Packet Type', 'Browser Name', 'Global Source IP')
# Found good ('Packet Type', 'Browser Name', 'Global Destination IP')
# Found good ('Packet Type', 'Browser Name', 'Is Proxy')
# Found good ('Packet Type', 'Browser Version', 'Browser Minor')
# Found good ('Packet Type', 'Browser Version', 'Browser Patch Minor')
# Found good ('Packet Type', 'Browser Version', 'OS Name')
# Found good ('Packet Type', 'Browser Version', 'OS Version Minor')
# Found good ('Packet Type', 'Browser Version', 'OS Version Patch')
# Found good ('Packet Type', 'Browser Version', 'OS Version Patch Minor')
# Time since start for 3200 combinations: 65.67 seconds
# Found good ('Packet Type', 'Browser Version', 'Device Brand')
# Found good ('Packet Type', 'Browser Version', 'Device Model')
# Found good ('Packet Type', 'Browser Version', 'Device Type')
# Found good ('Packet Type', 'Browser Version', 'Packet Bin')
# Found good ('Packet Type', 'Browser Version', 'Global Source IP')
# Found good ('Packet Type', 'Browser Version', 'Global Destination IP')
# Found good ('Packet Type', 'Browser Version', 'Is Proxy')
# Found good ('Packet Type', 'Browser Minor', 'Browser Patch')
# Found good ('Packet Type', 'Browser Minor', 'Browser Patch Minor')
# Found good ('Packet Type', 'Browser Minor', 'OS Name')
# Found good ('Packet Type', 'Browser Minor', 'OS Version Minor')
# Found good ('Packet Type', 'Browser Minor', 'OS Version Patch')
# Found good ('Packet Type', 'Browser Minor', 'OS Version Patch Minor')
# Found good ('Packet Type', 'Browser Minor', 'Packet Bin')
# Found good ('Packet Type', 'Browser Minor', 'Global Source IP')
# Found good ('Packet Type', 'Browser Minor', 'Global Destination IP')
# Found good ('Packet Type', 'Browser Minor', 'Is Proxy')
# Found good ('Packet Type', 'Browser Patch', 'Browser Patch Minor')
# Found good ('Packet Type', 'Browser Patch', 'OS Name')
# Found good ('Packet Type', 'Browser Patch', 'OS Version Patch Minor')
# Found good ('Packet Type', 'Browser Patch', 'Device Brand')
# Found good ('Packet Type', 'Browser Patch', 'Device Model')
# Found good ('Packet Type', 'Browser Patch', 'Device Type')
# Found good ('Packet Type', 'Browser Patch', 'Packet Bin')
# Found good ('Packet Type', 'Browser Patch', 'Global Source IP')
# Found good ('Packet Type', 'Browser Patch', 'Global Destination IP')
# Found good ('Packet Type', 'Browser Patch', 'Is Proxy')
# Found good ('Packet Type', 'Browser Patch Minor', 'OS Version')
# Found good ('Packet Type', 'Browser Patch Minor', 'OS Version Minor')
# Found good ('Packet Type', 'Browser Patch Minor', 'OS Version Patch')
# Found good ('Packet Type', 'Browser Patch Minor', 'Device Model')
# Found good ('Packet Type', 'Browser Patch Minor', 'Device Type')
# Found good ('Packet Type', 'Browser Patch Minor', 'Scale Packet Length')
# Found good ('Packet Type', 'OS Name', 'OS Version')
# Found good ('Packet Type', 'OS Name', 'OS Version Minor')
# Found good ('Packet Type', 'OS Name', 'OS Version Patch')
# Found good ('Packet Type', 'OS Name', 'Packet Bin')
# Found good ('Packet Type', 'OS Version', 'OS Version Minor')
# Found good ('Packet Type', 'OS Version', 'OS Version Patch')
# Found good ('Packet Type', 'OS Version', 'OS Version Patch Minor')
# Found good ('Packet Type', 'OS Version', 'Device Brand')
# Found good ('Packet Type', 'OS Version', 'Device Model')
# Found good ('Packet Type', 'OS Version', 'Device Type')
# Found good ('Packet Type', 'OS Version', 'Packet Bin')
# Found good ('Packet Type', 'OS Version', 'Global Source IP')
# Found good ('Packet Type', 'OS Version', 'Global Destination IP')
# Found good ('Packet Type', 'OS Version', 'Is Proxy')
# Found good ('Packet Type', 'OS Version Minor', 'OS Version Patch')
# Found good ('Packet Type', 'OS Version Minor', 'Device Brand')
# Found good ('Packet Type', 'OS Version Minor', 'Device Model')
# Found good ('Packet Type', 'OS Version Minor', 'Device Type')
# Found good ('Packet Type', 'OS Version Minor', 'Packet Bin')
# Found good ('Packet Type', 'OS Version Minor', 'Global Source IP')
# Found good ('Packet Type', 'OS Version Minor', 'Global Destination IP')
# Found good ('Packet Type', 'OS Version Minor', 'Is Proxy')
# Found good ('Packet Type', 'OS Version Patch', 'OS Version Patch Minor')
# Found good ('Packet Type', 'OS Version Patch', 'Device Brand')
# Found good ('Packet Type', 'OS Version Patch', 'Device Model')
# Time since start for 3300 combinations: 67.05 seconds
# Found good ('Packet Type', 'OS Version Patch', 'Device Type')
# Found good ('Packet Type', 'OS Version Patch', 'Packet Bin')
# Found good ('Packet Type', 'OS Version Patch', 'Global Source IP')
# Found good ('Packet Type', 'OS Version Patch', 'Global Destination IP')
# Found good ('Packet Type', 'OS Version Patch', 'Is Proxy')
# Found good ('Packet Type', 'OS Version Patch Minor', 'Scale Packet Length')
# Found good ('Packet Type', 'Device Brand', 'Packet Bin')
# Found good ('Packet Type', 'Device Brand', 'Scale Packet Length')
# Found good ('Packet Type', 'Device Model', 'Packet Bin')
# Found good ('Packet Type', 'Device Model', 'Global Source IP')
# Found good ('Packet Type', 'Device Model', 'Global Destination IP')
# Found good ('Packet Type', 'Device Model', 'Is Proxy')
# Found good ('Packet Type', 'Device Type', 'Packet Bin')
# Found good ('Packet Type', 'Device Type', 'Global Source IP')
# Found good ('Packet Type', 'Device Type', 'Global Destination IP')
# Found good ('Packet Type', 'Device Type', 'Is Proxy')
# Found good ('Packet Type', 'Packet Bin', 'Scale Packet Length')
# Found good ('Packet Type', 'Scale Packet Length', 'Global Source IP')
# Found good ('Packet Type', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Packet Type', 'Scale Packet Length', 'Is Proxy')
# Found good ('Traffic Type', 'Malware Indicators', 'Month')
# Found good ('Traffic Type', 'Malware Indicators', 'Day')
# Found good ('Traffic Type', 'Malware Indicators', 'Hour')
# Found good ('Traffic Type', 'Malware Indicators', 'Minute')
# Found good ('Traffic Type', 'Malware Indicators', 'Second')
# Found good ('Traffic Type', 'Malware Indicators', 'DayOfWeek')
# Found good ('Traffic Type', 'Malware Indicators', 'Browser Name')
# Found good ('Traffic Type', 'Malware Indicators', 'Browser Version')
# Found good ('Traffic Type', 'Malware Indicators', 'Browser Minor')
# Found good ('Traffic Type', 'Malware Indicators', 'Browser Patch')
# Found good ('Traffic Type', 'Malware Indicators', 'OS Name')
# Found good ('Traffic Type', 'Malware Indicators', 'OS Version')
# Found good ('Traffic Type', 'Malware Indicators', 'OS Version Minor')
# Found good ('Traffic Type', 'Malware Indicators', 'OS Version Patch')
# Found good ('Traffic Type', 'Malware Indicators', 'Device Model')
# Found good ('Traffic Type', 'Malware Indicators', 'Device Type')
# Found good ('Traffic Type', 'Malware Indicators', 'Scale Packet Length')
# Time since start for 3400 combinations: 68.40 seconds
# Found good ('Traffic Type', 'Alerts/Warnings', 'Month')
# Found good ('Traffic Type', 'Alerts/Warnings', 'Day')
# Found good ('Traffic Type', 'Alerts/Warnings', 'Hour')
# Found good ('Traffic Type', 'Alerts/Warnings', 'Minute')
# Found good ('Traffic Type', 'Alerts/Warnings', 'Second')
# Found good ('Traffic Type', 'Alerts/Warnings', 'DayOfWeek')
# Found good ('Traffic Type', 'Alerts/Warnings', 'Browser Name')
# Found good ('Traffic Type', 'Alerts/Warnings', 'Browser Version')
# Found good ('Traffic Type', 'Alerts/Warnings', 'Browser Minor')
# Found good ('Traffic Type', 'Alerts/Warnings', 'Browser Patch')
# Found good ('Traffic Type', 'Alerts/Warnings', 'OS Name')
# Found good ('Traffic Type', 'Alerts/Warnings', 'OS Version')
# Found good ('Traffic Type', 'Alerts/Warnings', 'OS Version Minor')
# Found good ('Traffic Type', 'Alerts/Warnings', 'OS Version Patch')
# Found good ('Traffic Type', 'Alerts/Warnings', 'Device Brand')
# Found good ('Traffic Type', 'Alerts/Warnings', 'Device Model')
# Found good ('Traffic Type', 'Alerts/Warnings', 'Device Type')
# Found good ('Traffic Type', 'Alerts/Warnings', 'Scale Packet Length')
# Found good ('Traffic Type', 'Attack Signature', 'Month')
# Found good ('Traffic Type', 'Attack Signature', 'Day')
# ...
# Found good ('Browser Patch', 'Device Model', 'Is Proxy')
# Found good ('Browser Patch', 'Device Type', 'Packet Bin')
# Found good ('Browser Patch', 'Device Type', 'Global Source IP')
# Found good ('Browser Patch', 'Device Type', 'Global Destination IP')
# Found good ('Browser Patch', 'Device Type', 'Is Proxy')
# Found good ('Browser Patch', 'Packet Bin', 'Global Source IP')
# Found good ('Browser Patch', 'Packet Bin', 'Global Destination IP')
# Found good ('Browser Patch', 'Packet Bin', 'Is Proxy')
# Found good ('Browser Patch', 'Global Source IP', 'Is Proxy')
# Found good ('Browser Patch', 'Global Destination IP', 'Is Proxy')
# Found good ('Browser Patch Minor', 'OS Name', 'OS Version')
# Found good ('Browser Patch Minor', 'OS Name', 'OS Version Minor')
# Found good ('Browser Patch Minor', 'OS Name', 'OS Version Patch')
# Found good ('Browser Patch Minor', 'OS Name', 'Global Source IP')
# Found good ('Browser Patch Minor', 'OS Name', 'Global Destination IP')
# Found good ('Browser Patch Minor', 'OS Version', 'OS Version Minor')
# Found good ('Browser Patch Minor', 'OS Version', 'OS Version Patch')
# Found good ('Browser Patch Minor', 'OS Version', 'OS Version Patch Minor')
# Time since start for 12700 combinations: 212.68 seconds
# Found good ('Browser Patch Minor', 'OS Version', 'Device Brand')
# Found good ('Browser Patch Minor', 'OS Version', 'Device Model')
# Found good ('Browser Patch Minor', 'OS Version', 'Device Type')
# Found good ('Browser Patch Minor', 'OS Version', 'Packet Bin')
# Found good ('Browser Patch Minor', 'OS Version', 'Global Source IP')
# Found good ('Browser Patch Minor', 'OS Version', 'Global Destination IP')
# Found good ('Browser Patch Minor', 'OS Version', 'Is Proxy')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'OS Version Patch')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'OS Version Patch Minor')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'Device Brand')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'Device Model')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'Device Type')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'Packet Bin')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'Global Source IP')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'Global Destination IP')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'Is Proxy')
# Found good ('Browser Patch Minor', 'OS Version Patch', 'OS Version Patch Minor')
# Found good ('Browser Patch Minor', 'OS Version Patch', 'Device Brand')
# Found good ('Browser Patch Minor', 'OS Version Patch', 'Device Model')
# Found good ('Browser Patch Minor', 'OS Version Patch', 'Device Type')
# Found good ('Browser Patch Minor', 'OS Version Patch', 'Packet Bin')
# Found good ('Browser Patch Minor', 'OS Version Patch', 'Global Source IP')
# Found good ('Browser Patch Minor', 'OS Version Patch', 'Global Destination IP')
# Found good ('Browser Patch Minor', 'OS Version Patch', 'Is Proxy')
# Found good ('Browser Patch Minor', 'OS Version Patch Minor', 'Scale Packet Length')
# Found good ('Browser Patch Minor', 'Device Model', 'Global Source IP')
# Found good ('Browser Patch Minor', 'Device Model', 'Global Destination IP')
# Found good ('Browser Patch Minor', 'Device Type', 'Global Source IP')
# Found good ('Browser Patch Minor', 'Device Type', 'Global Destination IP')
# Found good ('Browser Patch Minor', 'Packet Bin', 'Scale Packet Length')
# Found good ('Browser Patch Minor', 'Scale Packet Length', 'Global Source IP')
# Found good ('Browser Patch Minor', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Browser Patch Minor', 'Scale Packet Length', 'Is Proxy')
# Found good ('Browser Patch Minor', 'Global Source IP', 'Global Destination IP')
# Found good ('OS Name', 'OS Version', 'OS Version Minor')
# Found good ('OS Name', 'OS Version', 'OS Version Patch')
# Found good ('OS Name', 'OS Version', 'OS Version Patch Minor')
# Found good ('OS Name', 'OS Version', 'Device Brand')
# Found good ('OS Name', 'OS Version', 'Device Model')
# Found good ('OS Name', 'OS Version', 'Device Type')
# Found good ('OS Name', 'OS Version', 'Packet Bin')
# Found good ('OS Name', 'OS Version', 'Global Source IP')
# Found good ('OS Name', 'OS Version', 'Global Destination IP')
# Time since start for 12800 combinations: 214.40 seconds
# Found good ('OS Name', 'OS Version', 'Is Proxy')
# Found good ('OS Name', 'OS Version Minor', 'OS Version Patch')
# Found good ('OS Name', 'OS Version Minor', 'Device Model')
# Found good ('OS Name', 'OS Version Minor', 'Device Type')
# Found good ('OS Name', 'OS Version Minor', 'Packet Bin')
# Found good ('OS Name', 'OS Version Minor', 'Global Source IP')
# Found good ('OS Name', 'OS Version Minor', 'Global Destination IP')
# Found good ('OS Name', 'OS Version Minor', 'Is Proxy')
# Found good ('OS Name', 'OS Version Patch', 'OS Version Patch Minor')
# Found good ('OS Name', 'OS Version Patch', 'Device Brand')
# Found good ('OS Name', 'OS Version Patch', 'Device Model')
# Found good ('OS Name', 'OS Version Patch', 'Device Type')
# Found good ('OS Name', 'OS Version Patch', 'Packet Bin')
# Found good ('OS Name', 'OS Version Patch', 'Global Source IP')
# Found good ('OS Name', 'OS Version Patch', 'Global Destination IP')
# Found good ('OS Name', 'OS Version Patch', 'Is Proxy')
# Found good ('OS Name', 'OS Version Patch Minor', 'Scale Packet Length')
# Found good ('OS Name', 'Device Brand', 'Scale Packet Length')
# Found good ('OS Name', 'Device Model', 'Packet Bin')
# Found good ('OS Name', 'Device Model', 'Global Destination IP')
# Found good ('OS Name', 'Device Type', 'Packet Bin')
# Found good ('OS Name', 'Device Type', 'Global Destination IP')
# Found good ('OS Name', 'Packet Bin', 'Scale Packet Length')
# Found good ('OS Name', 'Packet Bin', 'Global Source IP')
# Found good ('OS Name', 'Scale Packet Length', 'Global Source IP')
# Found good ('OS Name', 'Scale Packet Length', 'Global Destination IP')
# Found good ('OS Name', 'Global Source IP', 'Global Destination IP')
# Found good ('OS Version', 'OS Version Minor', 'OS Version Patch')
# Found good ('OS Version', 'OS Version Minor', 'OS Version Patch Minor')
# Found good ('OS Version', 'OS Version Minor', 'Device Brand')
# Found good ('OS Version', 'OS Version Minor', 'Device Model')
# Found good ('OS Version', 'OS Version Minor', 'Device Type')
# Found good ('OS Version', 'OS Version Minor', 'Packet Bin')
# Found good ('OS Version', 'OS Version Minor', 'Global Source IP')
# Found good ('OS Version', 'OS Version Minor', 'Global Destination IP')
# Found good ('OS Version', 'OS Version Minor', 'Is Proxy')
# Found good ('OS Version', 'OS Version Patch', 'OS Version Patch Minor')
# Found good ('OS Version', 'OS Version Patch', 'Device Brand')
# Found good ('OS Version', 'OS Version Patch', 'Device Model')
# Found good ('OS Version', 'OS Version Patch', 'Device Type')
# Found good ('OS Version', 'OS Version Patch', 'Packet Bin')
# Found good ('OS Version', 'OS Version Patch', 'Global Source IP')
# Time since start for 12900 combinations: 216.15 seconds
# Found good ('OS Version', 'OS Version Patch', 'Global Destination IP')
# Found good ('OS Version', 'OS Version Patch', 'Is Proxy')
# Found good ('OS Version', 'OS Version Patch Minor', 'Device Brand')
# Found good ('OS Version', 'OS Version Patch Minor', 'Device Model')
# Found good ('OS Version', 'OS Version Patch Minor', 'Device Type')
# Found good ('OS Version', 'OS Version Patch Minor', 'Packet Bin')
# Found good ('OS Version', 'OS Version Patch Minor', 'Global Source IP')
# Found good ('OS Version', 'OS Version Patch Minor', 'Global Destination IP')
# Found good ('OS Version', 'OS Version Patch Minor', 'Is Proxy')
# Found good ('OS Version', 'Device Brand', 'Device Model')
# Found good ('OS Version', 'Device Brand', 'Device Type')
# Found good ('OS Version', 'Device Brand', 'Packet Bin')
# Found good ('OS Version', 'Device Brand', 'Global Source IP')
# Found good ('OS Version', 'Device Brand', 'Global Destination IP')
# Found good ('OS Version', 'Device Brand', 'Is Proxy')
# Found good ('OS Version', 'Device Model', 'Device Type')
# Found good ('OS Version', 'Device Model', 'Packet Bin')
# Found good ('OS Version', 'Device Model', 'Global Source IP')
# Found good ('OS Version', 'Device Model', 'Global Destination IP')
# Found good ('OS Version', 'Device Model', 'Is Proxy')
# Found good ('OS Version', 'Device Type', 'Packet Bin')
# Found good ('OS Version', 'Device Type', 'Global Source IP')
# Found good ('OS Version', 'Device Type', 'Global Destination IP')
# Found good ('OS Version', 'Device Type', 'Is Proxy')
# Found good ('OS Version', 'Packet Bin', 'Global Source IP')
# Found good ('OS Version', 'Packet Bin', 'Global Destination IP')
# Found good ('OS Version', 'Packet Bin', 'Is Proxy')
# Found good ('OS Version', 'Global Source IP', 'Global Destination IP')
# Found good ('OS Version', 'Global Source IP', 'Is Proxy')
# Found good ('OS Version', 'Global Destination IP', 'Is Proxy')
# Found good ('OS Version Minor', 'OS Version Patch', 'OS Version Patch Minor')
# Found good ('OS Version Minor', 'OS Version Patch', 'Device Brand')
# Found good ('OS Version Minor', 'OS Version Patch', 'Device Model')
# Found good ('OS Version Minor', 'OS Version Patch', 'Device Type')
# Found good ('OS Version Minor', 'OS Version Patch', 'Packet Bin')
# Found good ('OS Version Minor', 'OS Version Patch', 'Global Source IP')
# Found good ('OS Version Minor', 'OS Version Patch', 'Global Destination IP')
# Found good ('OS Version Minor', 'OS Version Patch', 'Is Proxy')
# Found good ('OS Version Minor', 'OS Version Patch Minor', 'Device Brand')
# Found good ('OS Version Minor', 'OS Version Patch Minor', 'Device Model')
# Found good ('OS Version Minor', 'OS Version Patch Minor', 'Device Type')
# Found good ('OS Version Minor', 'OS Version Patch Minor', 'Packet Bin')
# Found good ('OS Version Minor', 'OS Version Patch Minor', 'Global Source IP')
# Found good ('OS Version Minor', 'OS Version Patch Minor', 'Global Destination IP')
# Found good ('OS Version Minor', 'Device Brand', 'Device Model')
# Found good ('OS Version Minor', 'Device Brand', 'Device Type')
# Found good ('OS Version Minor', 'Device Brand', 'Packet Bin')
# Found good ('OS Version Minor', 'Device Brand', 'Global Source IP')
# Found good ('OS Version Minor', 'Device Brand', 'Global Destination IP')
# Found good ('OS Version Minor', 'Device Brand', 'Is Proxy')
# Found good ('OS Version Minor', 'Device Model', 'Device Type')
# Found good ('OS Version Minor', 'Device Model', 'Packet Bin')
# Found good ('OS Version Minor', 'Device Model', 'Global Source IP')
# Found good ('OS Version Minor', 'Device Model', 'Global Destination IP')
# Found good ('OS Version Minor', 'Device Model', 'Is Proxy')
# Found good ('OS Version Minor', 'Device Type', 'Packet Bin')
# Found good ('OS Version Minor', 'Device Type', 'Global Source IP')
# Time since start for 13000 combinations: 217.96 seconds
# Found good ('OS Version Minor', 'Device Type', 'Global Destination IP')
# Found good ('OS Version Minor', 'Device Type', 'Is Proxy')
# Found good ('OS Version Minor', 'Packet Bin', 'Global Source IP')
# Found good ('OS Version Minor', 'Packet Bin', 'Global Destination IP')
# Found good ('OS Version Minor', 'Packet Bin', 'Is Proxy')
# Found good ('OS Version Minor', 'Global Source IP', 'Global Destination IP')
# Found good ('OS Version Minor', 'Global Source IP', 'Is Proxy')
# Found good ('OS Version Minor', 'Global Destination IP', 'Is Proxy')
# Found good ('OS Version Patch', 'OS Version Patch Minor', 'Device Brand')
# Found good ('OS Version Patch', 'OS Version Patch Minor', 'Device Model')
# Found good ('OS Version Patch', 'OS Version Patch Minor', 'Device Type')
# Found good ('OS Version Patch', 'OS Version Patch Minor', 'Packet Bin')
# Found good ('OS Version Patch', 'OS Version Patch Minor', 'Global Source IP')
# Found good ('OS Version Patch', 'OS Version Patch Minor', 'Global Destination IP')
# Found good ('OS Version Patch', 'OS Version Patch Minor', 'Is Proxy')
# Found good ('OS Version Patch', 'Device Brand', 'Device Model')
# Found good ('OS Version Patch', 'Device Brand', 'Device Type')
# Found good ('OS Version Patch', 'Device Brand', 'Packet Bin')
# Found good ('OS Version Patch', 'Device Brand', 'Global Source IP')
# Found good ('OS Version Patch', 'Device Brand', 'Global Destination IP')
# Found good ('OS Version Patch', 'Device Brand', 'Is Proxy')
# Found good ('OS Version Patch', 'Device Model', 'Device Type')
# Found good ('OS Version Patch', 'Device Model', 'Packet Bin')
# Found good ('OS Version Patch', 'Device Model', 'Global Source IP')
# Found good ('OS Version Patch', 'Device Model', 'Global Destination IP')
# Found good ('OS Version Patch', 'Device Model', 'Is Proxy')
# Found good ('OS Version Patch', 'Device Type', 'Packet Bin')
# Found good ('OS Version Patch', 'Device Type', 'Global Source IP')
# Found good ('OS Version Patch', 'Device Type', 'Global Destination IP')
# Found good ('OS Version Patch', 'Device Type', 'Is Proxy')
# Found good ('OS Version Patch', 'Packet Bin', 'Global Source IP')
# Found good ('OS Version Patch', 'Packet Bin', 'Global Destination IP')
# Found good ('OS Version Patch', 'Packet Bin', 'Is Proxy')
# Found good ('OS Version Patch', 'Global Source IP', 'Global Destination IP')
# Found good ('OS Version Patch', 'Global Source IP', 'Is Proxy')
# Found good ('OS Version Patch', 'Global Destination IP', 'Is Proxy')
# Found good ('OS Version Patch Minor', 'Device Brand', 'Scale Packet Length')
# Found good ('OS Version Patch Minor', 'Device Model', 'Global Source IP')
# Found good ('OS Version Patch Minor', 'Device Model', 'Global Destination IP')
# Found good ('OS Version Patch Minor', 'Device Type', 'Global Source IP')
# Time since start for 13100 combinations: 219.80 seconds
# Found good ('OS Version Patch Minor', 'Device Type', 'Global Destination IP')
# Found good ('OS Version Patch Minor', 'Packet Bin', 'Scale Packet Length')
# Found good ('OS Version Patch Minor', 'Scale Packet Length', 'Global Source IP')
# Found good ('OS Version Patch Minor', 'Scale Packet Length', 'Global Destination IP')
# Found good ('OS Version Patch Minor', 'Scale Packet Length', 'Is Proxy')
# Found good ('OS Version Patch Minor', 'Global Source IP', 'Global Destination IP')
# Found good ('Device Brand', 'Device Model', 'Global Source IP')
# Found good ('Device Brand', 'Device Model', 'Global Destination IP')
# Found good ('Device Brand', 'Device Type', 'Global Source IP')
# Found good ('Device Brand', 'Device Type', 'Global Destination IP')
# Found good ('Device Brand', 'Packet Bin', 'Scale Packet Length')
# Found good ('Device Brand', 'Scale Packet Length', 'Global Source IP')
# Found good ('Device Brand', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Device Brand', 'Scale Packet Length', 'Is Proxy')
# Found good ('Device Brand', 'Global Source IP', 'Global Destination IP')
# Found good ('Device Model', 'Device Type', 'Global Source IP')
# Found good ('Device Model', 'Device Type', 'Global Destination IP')
# Found good ('Device Model', 'Packet Bin', 'Global Source IP')
# Found good ('Device Model', 'Packet Bin', 'Global Destination IP')
# Found good ('Device Model', 'Packet Bin', 'Is Proxy')
# Found good ('Device Model', 'Global Source IP', 'Global Destination IP')
# Found good ('Device Model', 'Global Source IP', 'Is Proxy')
# Found good ('Device Model', 'Global Destination IP', 'Is Proxy')
# Found good ('Device Type', 'Packet Bin', 'Global Source IP')
# Found good ('Device Type', 'Packet Bin', 'Global Destination IP')
# Found good ('Device Type', 'Packet Bin', 'Is Proxy')
# Time since start for 13200 combinations: 221.73 seconds
# Found good ('Device Type', 'Global Source IP', 'Global Destination IP')
# Found good ('Device Type', 'Global Source IP', 'Is Proxy')
# Found good ('Device Type', 'Global Destination IP', 'Is Proxy')
# Found good ('Packet Bin', 'Scale Packet Length', 'Global Source IP')
# Found good ('Packet Bin', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Packet Bin', 'Scale Packet Length', 'Is Proxy')
# Found good ('Scale Packet Length', 'Global Source IP', 'Global Destination IP')
# Found good ('Scale Packet Length', 'Global Source IP', 'Is Proxy')
# Found good ('Scale Packet Length', 'Global Destination IP', 'Is Proxy')

# %%
combination = good_combinations_df.iloc[0,0:3].tolist()
columns = deepcopy(combination)
columns.append("Attack Type")

temp_data = cleaned_data[columns]
temp_data = temp_data.pivot_table(
    index=combination,  
    columns="Attack Type",
    aggfunc="count",
    fill_value=0
)
temp_data["Total"]= temp_data.sum(axis=1)
# Get unique combinations of first 3 features
unique_combos = temp_data.index.unique()
attack_types = ["DDoS", "Malware", "Intrusion"]

# Create subplots - one for each (Traffic Type, Protocol, Packet Type) combination
num_combos = len(unique_combos)
nb_cols = 9
nb_rows = (num_combos + nb_cols -1) // nb_cols  # 3 columns per row

fig = make_subplots(
    rows=nb_rows,
    cols=nb_cols,
    subplot_titles=[f"{c[0]} | {c[1]} | {c[2]}" for c in unique_combos],
    horizontal_spacing=0.05,
    vertical_spacing=0.05,
)

for idx, combo in enumerate(unique_combos):
    row = (idx // nb_cols) + 1
    col = (idx % nb_cols) + 1
    for i, attack_type in enumerate(attack_types):
        fig.add_trace(
            go.Bar(
                x=[attack_type],
                y=[temp_data.loc[combo, attack_type]],
                name=attack_type,
                marker_color=palette[i % len(palette)],
                legendgroup=attack_type,
                showlegend=False
            ),
            row=row, col=col
        )
        
    fig.update_xaxes(title_text="Combo", row=row, col=col, tickangle=-45)
    fig.update_yaxes(title_text="Count", row=row, col=col)

fig.update_layout(
    height=400 * nb_rows,
    width=1600,
    title={
        'text': f"Combinations for each ({', '.join(combination)})",
        'y': 0.98,
        'x': 0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    barmode='group',
    showlegend=True
)

fig.show()

# %%
temp_data["Total"]= temp_data.sum(axis=1)
# Calculate percentages for each tuple (row-wise)
for attack_type in attack_types:
    temp_data[f"{attack_type} %"] = (temp_data[attack_type] / temp_data['Total'] * 100).round(2)


# Calculate difference between max and min percentage for each tuple (row-wise)
percentage_cols = [f"{attack_type} %" for attack_type in attack_types]
temp_data['Max-Min Diff %'] = (temp_data[percentage_cols].max(axis=1) - temp_data[percentage_cols].min(axis=1)).round(2)

# Reorder columns to show count and percentage together
new_order = []
for attack_type in attack_types:
    new_order.append(attack_type)
    new_order.append(f"{attack_type} %")
new_order.extend(['Total', 'Max-Min Diff %'])
temp_data = temp_data[new_order]
temp_data.describe()
# Out:
# Attack Type        DDoS     DDoS %     Malware  Malware %   Intrusion  \
# count         72.000000  72.000000   72.000000  72.000000   72.000000
# mean         186.500000  16.785139  184.819444  16.642639  184.236111
# std           23.975927   1.069657   22.762909   0.961923   24.023752
# min          132.000000  14.180000  136.000000  13.950000  128.000000
# 25%          173.000000  16.060000  169.000000  15.865000  169.000000
# 50%          191.000000  16.885000  186.000000  16.725000  188.000000
# 75%          203.000000  17.347500  203.250000  17.275000  199.250000
# max          236.000000  19.380000  241.000000  19.440000  234.000000
#
# Attack Type  Intrusion %        Total  Max-Min Diff %
# count          72.000000    72.000000       72.000000
# mean           16.572361  1111.111111        2.052500
# std             0.971761   124.292653        1.143762
# min            13.450000   836.000000        0.080000
# 25%            15.910000  1045.000000        1.357500
# 50%            16.640000  1145.000000        1.780000
# 75%            17.202500  1202.500000        2.812500
# max            18.540000  1270.000000        5.930000

# %%
columns = ["IsWeekend", "Hour", "Attack Type"]
combination = ["IsWeekend", "Hour"]
temp_data = cleaned_data[columns]
temp_data = temp_data.pivot_table(
    index=combination,  
    columns="Attack Type",
    aggfunc="count",
    fill_value=0
)

# %%
# Get unique combinations of first 3 features
unique_combos = temp_data.index.unique()
attack_types = ["DDoS", "Malware", "Intrusion"]

# Create subplots - one for each (Traffic Type, Protocol, Packet Type) combination
num_combos = len(unique_combos)
nb_cols = 8
nb_rows = (num_combos + nb_cols -1) // nb_cols  # 3 columns per row

fig = make_subplots(
    rows=nb_rows,
    cols=nb_cols,
    subplot_titles=[f"{c[0]} | {c[1]}" for c in unique_combos],
    vertical_spacing=0.1,
    horizontal_spacing=0.05,
)

for idx, combo in enumerate(unique_combos):
    row = (idx // nb_cols) + 1
    col = (idx % nb_cols) + 1
    for i, attack_type in enumerate(attack_types):
        fig.add_trace(
            go.Bar(
                x=[attack_type],
                y=[temp_data.loc[combo, attack_type]],
                name=attack_type,
                marker_color=palette[i % len(palette)],
                legendgroup=attack_type,
                showlegend=False
            ),
            row=row, col=col
        )
        
    fig.update_xaxes(title_text="Combo", row=row, col=col, tickangle=-45)
    fig.update_yaxes(title_text="Count", row=row, col=col)

fig.update_layout(
    height=200 * nb_rows,
    width=1600,
    title={
        'text': f"Combinations for each ({', '.join(combination)})",
        'y': 0.98,
        'x': 0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    barmode='group',
    showlegend=True
)

fig.show()

# %%
temp_data["Total"]= temp_data.sum(axis=1)
# Calculate percentages for each tuple (row-wise)
for attack_type in attack_types:
    temp_data[f"{attack_type} %"] = (temp_data[attack_type] / temp_data['Total'] * 100).round(2)


# Calculate difference between max and min percentage for each tuple (row-wise)
percentage_cols = [f"{attack_type} %" for attack_type in attack_types]
temp_data['Max-Min Diff %'] = (temp_data[percentage_cols].max(axis=1) - temp_data[percentage_cols].min(axis=1)).round(2)

# Reorder columns to show count and percentage together
new_order = []
for attack_type in attack_types:
    new_order.append(attack_type)
    new_order.append(f"{attack_type} %")
new_order.extend(['Total', 'Max-Min Diff %'])
temp_data = temp_data[new_order]
temp_data.describe()
# Out:
# Attack Type        DDoS     DDoS %     Malware  Malware %   Intrusion  \
# count         48.000000  48.000000   48.000000  48.000000   48.000000
# mean         279.750000  33.388750  277.229167  33.325417  276.354167
# std          125.358804   1.891103  120.418992   1.585159  119.044152
# min          129.000000  28.540000  142.000000  29.770000  140.000000
# 25%          159.750000  32.137500  157.500000  32.535000  162.250000
# 50%          275.500000  33.435000  272.000000  33.020000  269.000000
# 75%          401.250000  34.667500  395.750000  34.202500  393.750000
# max          442.000000  37.550000  429.000000  37.680000  436.000000
#
# Attack Type  Intrusion %        Total  Max-Min Diff %
# count          48.000000    48.000000       48.000000
# mean           33.285833   833.333333        3.541458
# std             1.700051   362.961010        1.977164
# min            30.170000   444.000000        0.420000
# 25%            32.075000   473.750000        2.127500
# 50%            33.410000   825.500000        2.985000
# 75%            34.412500  1197.250000        4.795000
# max            36.770000  1254.000000        9.070000

# %%
main_features = good_combinations_df.iloc[:,0:2].value_counts()

# %% [markdown]
# From this we can see a pattern: datetime information seems to give a good idea of how input data can be separated. The top combinations all include one part of a datetime in the first two features. <br>
# We will use these features as combinations of their own as they are similar features. <br>
# We then remove this features from the data and redo to filter to see if we can find other combinations.

# %%
relaunch = ""
while relaunch.lower() not in ["y","n"]:
    relaunch = input("Do you want to relaunch the analysis to find good combinations without date features? (y/n) ")
if relaunch.lower() == "y":
    data_wo_date = cleaned_data.copy().drop(columns=["Day", "Month", "Year","Hour","Minute", "Second","IsWeekend","DayOfWeek"])
    col_combinations = [col for col in data_wo_date.columns if col != "Attack Type"]
    col_combinations = list(combinations(col_combinations,3))

    nb_rows=data_wo_date.shape[0]
    good_combinations = []
    start_time = time.monotonic()
    for i,combination in enumerate(col_combinations):
        columns = [col for col in combination]+["Attack Type"]
        temp_data = data_wo_date[columns]
        temp_data = temp_data.pivot_table(
            index=combination,  
            columns="Attack Type",
            aggfunc="count",
            fill_value=0
        )
        temp_data["Total"]= temp_data.sum(axis=1)
        percentage_data = temp_data[["DDoS","Malware", "Intrusion"]].div(temp_data["Total"], axis=0)
        percentage_data = percentage_data.max(axis=1) - percentage_data.min(axis=1)
        stats = percentage_data.describe()
        if stats.loc["25%"] > 0.02 and stats.loc["75%"] < 0.99:
            print(f"Found good {combination}")
            output = [feature for feature in combination]
            output.extend([f"%.4f" % stats.loc[x] for x in stats.index])
            good_combinations.append(output)
        if i%100==0 and i!=0:
            print(f"Time since start for {i:d} combinations: {time.monotonic() - start_time:.2f} seconds")
    print(f"Total time: {time.monotonic() - start_time} seconds")
    combinations_wo_date_df = pd.DataFrame(good_combinations, columns=["Feature 1", "Feature 2", "Feature 3", 'count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'])
    combinations_wo_date_df.to_csv(path.joinpath("combinations_wo_date.csv"), index=False)
else:
    combinations_wo_date_df = pd.read_csv(path.joinpath("combinations_wo_date.csv"))
# Out:
# Time since start for 100 combinations: 2.67 seconds
# Time since start for 200 combinations: 5.26 seconds
# Time since start for 300 combinations: 7.88 seconds
# Time since start for 400 combinations: 10.86 seconds
# Time since start for 500 combinations: 13.72 seconds
# Time since start for 600 combinations: 16.46 seconds
# Time since start for 700 combinations: 19.07 seconds
# Time since start for 800 combinations: 21.64 seconds
# Time since start for 900 combinations: 24.42 seconds
# Time since start for 1000 combinations: 27.21 seconds
# Time since start for 1100 combinations: 29.93 seconds
# Found good ('Protocol', 'Packet Type', 'Browser Name')
# Found good ('Protocol', 'Packet Type', 'Browser Version')
# Found good ('Protocol', 'Packet Type', 'Browser Minor')
# Found good ('Protocol', 'Packet Type', 'Browser Patch')
# Found good ('Protocol', 'Packet Type', 'OS Version')
# Found good ('Protocol', 'Packet Type', 'OS Version Minor')
# Found good ('Protocol', 'Packet Type', 'OS Version Patch')
# Found good ('Protocol', 'Packet Type', 'Device Model')
# Found good ('Protocol', 'Packet Type', 'Device Type')
# Found good ('Protocol', 'Packet Type', 'Scale Packet Length')
# Found good ('Protocol', 'Traffic Type', 'Browser Name')
# Found good ('Protocol', 'Traffic Type', 'Browser Version')
# Time since start for 1200 combinations: 31.84 seconds
# Found good ('Protocol', 'Traffic Type', 'Browser Minor')
# Found good ('Protocol', 'Traffic Type', 'Browser Patch')
# Found good ('Protocol', 'Traffic Type', 'OS Name')
# Found good ('Protocol', 'Traffic Type', 'OS Version')
# Found good ('Protocol', 'Traffic Type', 'OS Version Minor')
# Found good ('Protocol', 'Traffic Type', 'OS Version Patch')
# Found good ('Protocol', 'Traffic Type', 'Device Brand')
# Found good ('Protocol', 'Traffic Type', 'Device Model')
# Found good ('Protocol', 'Traffic Type', 'Device Type')
# Found good ('Protocol', 'Malware Indicators', 'Browser Name')
# Found good ('Protocol', 'Malware Indicators', 'Browser Version')
# Found good ('Protocol', 'Malware Indicators', 'Browser Minor')
# Found good ('Protocol', 'Malware Indicators', 'Browser Patch')
# Found good ('Protocol', 'Malware Indicators', 'OS Version')
# Found good ('Protocol', 'Malware Indicators', 'OS Version Minor')
# Found good ('Protocol', 'Malware Indicators', 'OS Version Patch')
# Found good ('Protocol', 'Malware Indicators', 'Device Model')
# Found good ('Protocol', 'Malware Indicators', 'Device Type')
# Found good ('Protocol', 'Malware Indicators', 'Scale Packet Length')
# Found good ('Protocol', 'Alerts/Warnings', 'Browser Name')
# Found good ('Protocol', 'Alerts/Warnings', 'Browser Version')
# Found good ('Protocol', 'Alerts/Warnings', 'Browser Minor')
# Found good ('Protocol', 'Alerts/Warnings', 'Browser Patch')
# Found good ('Protocol', 'Alerts/Warnings', 'OS Version')
# Found good ('Protocol', 'Alerts/Warnings', 'OS Version Minor')
# Found good ('Protocol', 'Alerts/Warnings', 'OS Version Patch')
# Found good ('Protocol', 'Alerts/Warnings', 'Device Model')
# Found good ('Protocol', 'Alerts/Warnings', 'Device Type')
# Found good ('Protocol', 'Alerts/Warnings', 'Scale Packet Length')
# Time since start for 1300 combinations: 33.27 seconds
# Found good ('Protocol', 'Attack Signature', 'Browser Name')
# Found good ('Protocol', 'Attack Signature', 'Browser Version')
# Found good ('Protocol', 'Attack Signature', 'Browser Minor')
# Found good ('Protocol', 'Attack Signature', 'Browser Patch')
# Found good ('Protocol', 'Attack Signature', 'OS Version')
# Found good ('Protocol', 'Attack Signature', 'OS Version Minor')
# Found good ('Protocol', 'Attack Signature', 'OS Version Patch')
# Found good ('Protocol', 'Attack Signature', 'Scale Packet Length')
# Found good ('Protocol', 'Action Taken', 'Browser Name')
# Found good ('Protocol', 'Action Taken', 'Browser Version')
# Found good ('Protocol', 'Action Taken', 'Browser Minor')
# Found good ('Protocol', 'Action Taken', 'Browser Patch')
# Found good ('Protocol', 'Action Taken', 'OS Name')
# Found good ('Protocol', 'Action Taken', 'OS Version')
# Found good ('Protocol', 'Action Taken', 'OS Version Minor')
# Found good ('Protocol', 'Action Taken', 'OS Version Patch')
# Found good ('Protocol', 'Action Taken', 'Device Brand')
# Found good ('Protocol', 'Action Taken', 'Device Model')
# Found good ('Protocol', 'Action Taken', 'Device Type')
# Found good ('Protocol', 'Action Taken', 'Scale Packet Length')
# Found good ('Protocol', 'Severity Level', 'Browser Name')
# Found good ('Protocol', 'Severity Level', 'Browser Version')
# Found good ('Protocol', 'Severity Level', 'Browser Minor')
# Found good ('Protocol', 'Severity Level', 'Browser Patch')
# Found good ('Protocol', 'Severity Level', 'OS Name')
# Found good ('Protocol', 'Severity Level', 'OS Version')
# Found good ('Protocol', 'Severity Level', 'OS Version Minor')
# Found good ('Protocol', 'Severity Level', 'OS Version Patch')
# Found good ('Protocol', 'Severity Level', 'Device Model')
# Found good ('Protocol', 'Severity Level', 'Device Type')
# Found good ('Protocol', 'Network Segment', 'Browser Name')
# Found good ('Protocol', 'Network Segment', 'Browser Version')
# Found good ('Protocol', 'Network Segment', 'Browser Minor')
# Found good ('Protocol', 'Network Segment', 'Browser Patch')
# Found good ('Protocol', 'Network Segment', 'OS Version')
# Found good ('Protocol', 'Network Segment', 'OS Version Minor')
# Found good ('Protocol', 'Network Segment', 'OS Version Patch')
# Found good ('Protocol', 'Network Segment', 'Device Model')
# Found good ('Protocol', 'Network Segment', 'Device Type')
# Time since start for 1400 combinations: 34.40 seconds
# Found good ('Protocol', 'Network Segment', 'Packet Bin')
# Found good ('Protocol', 'Firewall Logs', 'Browser Name')
# Found good ('Protocol', 'Firewall Logs', 'Browser Version')
# Found good ('Protocol', 'Firewall Logs', 'Browser Minor')
# Found good ('Protocol', 'Firewall Logs', 'Browser Patch')
# Found good ('Protocol', 'Firewall Logs', 'OS Version')
# Found good ('Protocol', 'Firewall Logs', 'OS Version Minor')
# Found good ('Protocol', 'Firewall Logs', 'OS Version Patch')
# Found good ('Protocol', 'Firewall Logs', 'Device Model')
# Found good ('Protocol', 'Firewall Logs', 'Device Type')
# Found good ('Protocol', 'Firewall Logs', 'Scale Packet Length')
# Found good ('Protocol', 'IDS/IPS Alerts', 'Browser Name')
# Found good ('Protocol', 'IDS/IPS Alerts', 'Browser Version')
# Found good ('Protocol', 'IDS/IPS Alerts', 'Browser Minor')
# Found good ('Protocol', 'IDS/IPS Alerts', 'Browser Patch')
# Found good ('Protocol', 'IDS/IPS Alerts', 'OS Version')
# Found good ('Protocol', 'IDS/IPS Alerts', 'OS Version Minor')
# Found good ('Protocol', 'IDS/IPS Alerts', 'OS Version Patch')
# Found good ('Protocol', 'IDS/IPS Alerts', 'Device Model')
# Found good ('Protocol', 'IDS/IPS Alerts', 'Device Type')
# Found good ('Protocol', 'IDS/IPS Alerts', 'Scale Packet Length')
# Found good ('Protocol', 'Log Source', 'Browser Name')
# Found good ('Protocol', 'Log Source', 'Browser Version')
# Found good ('Protocol', 'Log Source', 'Browser Minor')
# Found good ('Protocol', 'Log Source', 'Browser Patch')
# Found good ('Protocol', 'Log Source', 'OS Version')
# Found good ('Protocol', 'Log Source', 'OS Version Minor')
# Found good ('Protocol', 'Log Source', 'OS Version Patch')
# Found good ('Protocol', 'Log Source', 'Device Model')
# Found good ('Protocol', 'Log Source', 'Device Type')
# Found good ('Protocol', 'Log Source', 'Scale Packet Length')
# Found good ('Protocol', 'Browser Name', 'Browser Version')
# Found good ('Protocol', 'Browser Name', 'Browser Minor')
# Found good ('Protocol', 'Browser Name', 'Browser Patch')
# Found good ('Protocol', 'Browser Name', 'Browser Patch Minor')
# Found good ('Protocol', 'Browser Name', 'OS Name')
# Found good ('Protocol', 'Browser Name', 'OS Version')
# Found good ('Protocol', 'Browser Name', 'OS Version Minor')
# Time since start for 1500 combinations: 36.06 seconds
# Found good ('Protocol', 'Browser Name', 'OS Version Patch')
# Found good ('Protocol', 'Browser Name', 'OS Version Patch Minor')
# Found good ('Protocol', 'Browser Name', 'Device Brand')
# Found good ('Protocol', 'Browser Name', 'Device Model')
# Found good ('Protocol', 'Browser Name', 'Device Type')
# Found good ('Protocol', 'Browser Name', 'Packet Bin')
# Found good ('Protocol', 'Browser Name', 'Global Source IP')
# Found good ('Protocol', 'Browser Name', 'Global Destination IP')
# Found good ('Protocol', 'Browser Name', 'Is Proxy')
# Found good ('Protocol', 'Browser Version', 'Browser Minor')
# Found good ('Protocol', 'Browser Version', 'Browser Patch Minor')
# Found good ('Protocol', 'Browser Version', 'OS Name')
# Found good ('Protocol', 'Browser Version', 'OS Version Patch Minor')
# Found good ('Protocol', 'Browser Version', 'Device Brand')
# Found good ('Protocol', 'Browser Version', 'Device Model')
# Found good ('Protocol', 'Browser Version', 'Device Type')
# Found good ('Protocol', 'Browser Version', 'Packet Bin')
# Found good ('Protocol', 'Browser Version', 'Global Source IP')
# Found good ('Protocol', 'Browser Version', 'Global Destination IP')
# Found good ('Protocol', 'Browser Version', 'Is Proxy')
# Found good ('Protocol', 'Browser Minor', 'Browser Patch')
# Found good ('Protocol', 'Browser Minor', 'Browser Patch Minor')
# Found good ('Protocol', 'Browser Minor', 'OS Name')
# Found good ('Protocol', 'Browser Minor', 'OS Version Minor')
# Found good ('Protocol', 'Browser Minor', 'OS Version Patch')
# Found good ('Protocol', 'Browser Minor', 'OS Version Patch Minor')
# Found good ('Protocol', 'Browser Minor', 'Packet Bin')
# Found good ('Protocol', 'Browser Minor', 'Global Source IP')
# Found good ('Protocol', 'Browser Minor', 'Global Destination IP')
# Found good ('Protocol', 'Browser Minor', 'Is Proxy')
# Found good ('Protocol', 'Browser Patch', 'Browser Patch Minor')
# Found good ('Protocol', 'Browser Patch', 'OS Name')
# Found good ('Protocol', 'Browser Patch', 'OS Version Patch Minor')
# Found good ('Protocol', 'Browser Patch', 'Device Brand')
# Found good ('Protocol', 'Browser Patch', 'Device Model')
# Found good ('Protocol', 'Browser Patch', 'Device Type')
# Found good ('Protocol', 'Browser Patch', 'Packet Bin')
# Found good ('Protocol', 'Browser Patch', 'Global Source IP')
# Found good ('Protocol', 'Browser Patch', 'Global Destination IP')
# Found good ('Protocol', 'Browser Patch', 'Is Proxy')
# Found good ('Protocol', 'Browser Patch Minor', 'OS Version')
# Found good ('Protocol', 'Browser Patch Minor', 'OS Version Minor')
# Found good ('Protocol', 'Browser Patch Minor', 'OS Version Patch')
# Found good ('Protocol', 'Browser Patch Minor', 'Device Model')
# Found good ('Protocol', 'Browser Patch Minor', 'Device Type')
# Found good ('Protocol', 'Browser Patch Minor', 'Scale Packet Length')
# Found good ('Protocol', 'OS Name', 'OS Version')
# Found good ('Protocol', 'OS Name', 'OS Version Minor')
# Found good ('Protocol', 'OS Name', 'OS Version Patch')
# Found good ('Protocol', 'OS Name', 'Is Proxy')
# Found good ('Protocol', 'OS Version', 'OS Version Minor')
# Found good ('Protocol', 'OS Version', 'OS Version Patch')
# Found good ('Protocol', 'OS Version', 'OS Version Patch Minor')
# Found good ('Protocol', 'OS Version', 'Device Brand')
# Found good ('Protocol', 'OS Version', 'Device Model')
# Found good ('Protocol', 'OS Version', 'Device Type')
# Found good ('Protocol', 'OS Version', 'Packet Bin')
# Time since start for 1600 combinations: 37.44 seconds
# Found good ('Protocol', 'OS Version', 'Global Source IP')
# Found good ('Protocol', 'OS Version', 'Global Destination IP')
# Found good ('Protocol', 'OS Version', 'Is Proxy')
# Found good ('Protocol', 'OS Version Minor', 'OS Version Patch')
# Found good ('Protocol', 'OS Version Minor', 'OS Version Patch Minor')
# Found good ('Protocol', 'OS Version Minor', 'Device Brand')
# Found good ('Protocol', 'OS Version Minor', 'Device Model')
# Found good ('Protocol', 'OS Version Minor', 'Device Type')
# Found good ('Protocol', 'OS Version Minor', 'Packet Bin')
# Found good ('Protocol', 'OS Version Minor', 'Global Source IP')
# Found good ('Protocol', 'OS Version Minor', 'Global Destination IP')
# Found good ('Protocol', 'OS Version Minor', 'Is Proxy')
# Found good ('Protocol', 'OS Version Patch', 'OS Version Patch Minor')
# Found good ('Protocol', 'OS Version Patch', 'Device Brand')
# Found good ('Protocol', 'OS Version Patch', 'Device Model')
# Found good ('Protocol', 'OS Version Patch', 'Device Type')
# Found good ('Protocol', 'OS Version Patch', 'Packet Bin')
# Found good ('Protocol', 'OS Version Patch', 'Global Source IP')
# Found good ('Protocol', 'OS Version Patch', 'Global Destination IP')
# Found good ('Protocol', 'OS Version Patch', 'Is Proxy')
# Found good ('Protocol', 'OS Version Patch Minor', 'Scale Packet Length')
# Found good ('Protocol', 'Device Brand', 'Packet Bin')
# Found good ('Protocol', 'Device Model', 'Packet Bin')
# Found good ('Protocol', 'Device Model', 'Global Destination IP')
# Found good ('Protocol', 'Device Model', 'Is Proxy')
# Found good ('Protocol', 'Device Type', 'Packet Bin')
# Found good ('Protocol', 'Device Type', 'Global Destination IP')
# Found good ('Protocol', 'Device Type', 'Is Proxy')
# Found good ('Protocol', 'Packet Bin', 'Scale Packet Length')
# Found good ('Protocol', 'Scale Packet Length', 'Global Source IP')
# Found good ('Protocol', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Protocol', 'Scale Packet Length', 'Is Proxy')
# Found good ('Packet Type', 'Traffic Type', 'Browser Name')
# Found good ('Packet Type', 'Traffic Type', 'Browser Version')
# Found good ('Packet Type', 'Traffic Type', 'Browser Minor')
# Found good ('Packet Type', 'Traffic Type', 'Browser Patch')
# Time since start for 1700 combinations: 38.89 seconds
# Found good ('Packet Type', 'Traffic Type', 'OS Version')
# Found good ('Packet Type', 'Traffic Type', 'OS Version Minor')
# Found good ('Packet Type', 'Traffic Type', 'OS Version Patch')
# Found good ('Packet Type', 'Traffic Type', 'Device Model')
# Found good ('Packet Type', 'Traffic Type', 'Device Type')
# Found good ('Packet Type', 'Traffic Type', 'Scale Packet Length')
# Found good ('Packet Type', 'Malware Indicators', 'Browser Name')
# Found good ('Packet Type', 'Malware Indicators', 'Browser Version')
# Found good ('Packet Type', 'Malware Indicators', 'Browser Minor')
# Found good ('Packet Type', 'Malware Indicators', 'Browser Patch')
# Found good ('Packet Type', 'Malware Indicators', 'OS Version')
# Found good ('Packet Type', 'Malware Indicators', 'OS Version Minor')
# Found good ('Packet Type', 'Malware Indicators', 'OS Version Patch')
# Found good ('Packet Type', 'Malware Indicators', 'Device Model')
# Found good ('Packet Type', 'Malware Indicators', 'Device Type')
# Found good ('Packet Type', 'Malware Indicators', 'Scale Packet Length')
# Found good ('Packet Type', 'Alerts/Warnings', 'Browser Name')
# Found good ('Packet Type', 'Alerts/Warnings', 'Browser Version')
# Found good ('Packet Type', 'Alerts/Warnings', 'Browser Minor')
# Found good ('Packet Type', 'Alerts/Warnings', 'Browser Patch')
# Found good ('Packet Type', 'Alerts/Warnings', 'OS Version')
# Found good ('Packet Type', 'Alerts/Warnings', 'OS Version Minor')
# Found good ('Packet Type', 'Alerts/Warnings', 'OS Version Patch')
# Found good ('Packet Type', 'Alerts/Warnings', 'Device Model')
# Found good ('Packet Type', 'Alerts/Warnings', 'Device Type')
# Found good ('Packet Type', 'Alerts/Warnings', 'Scale Packet Length')
# Time since start for 1800 combinations: 40.32 seconds
# Found good ('Packet Type', 'Attack Signature', 'Browser Name')
# Found good ('Packet Type', 'Attack Signature', 'Browser Version')
# Found good ('Packet Type', 'Attack Signature', 'Browser Minor')
# Found good ('Packet Type', 'Attack Signature', 'Browser Patch')
# Found good ('Packet Type', 'Attack Signature', 'OS Version')
# Found good ('Packet Type', 'Attack Signature', 'OS Version Minor')
# Found good ('Packet Type', 'Attack Signature', 'OS Version Patch')
# Found good ('Packet Type', 'Attack Signature', 'Device Model')
# Found good ('Packet Type', 'Attack Signature', 'Device Type')
# Found good ('Packet Type', 'Attack Signature', 'Packet Bin')
# Found good ('Packet Type', 'Attack Signature', 'Scale Packet Length')
# Found good ('Packet Type', 'Action Taken', 'Browser Name')
# Found good ('Packet Type', 'Action Taken', 'Browser Version')
# Found good ('Packet Type', 'Action Taken', 'Browser Minor')
# Found good ('Packet Type', 'Action Taken', 'Browser Patch')
# Found good ('Packet Type', 'Action Taken', 'OS Version')
# Found good ('Packet Type', 'Action Taken', 'OS Version Minor')
# Found good ('Packet Type', 'Action Taken', 'OS Version Patch')
# Found good ('Packet Type', 'Action Taken', 'Device Model')
# Found good ('Packet Type', 'Action Taken', 'Device Type')
# Found good ('Packet Type', 'Action Taken', 'Scale Packet Length')
# Found good ('Packet Type', 'Severity Level', 'Browser Name')
# Found good ('Packet Type', 'Severity Level', 'Browser Version')
# Found good ('Packet Type', 'Severity Level', 'Browser Minor')
# Found good ('Packet Type', 'Severity Level', 'Browser Patch')
# Found good ('Packet Type', 'Severity Level', 'OS Version')
# Found good ('Packet Type', 'Severity Level', 'OS Version Minor')
# Found good ('Packet Type', 'Severity Level', 'OS Version Patch')
# Found good ('Packet Type', 'Severity Level', 'Device Model')
# Found good ('Packet Type', 'Severity Level', 'Device Type')
# Found good ('Packet Type', 'Severity Level', 'Scale Packet Length')
# Found good ('Packet Type', 'Network Segment', 'Browser Name')
# Found good ('Packet Type', 'Network Segment', 'Browser Version')
# Found good ('Packet Type', 'Network Segment', 'Browser Minor')
# Found good ('Packet Type', 'Network Segment', 'Browser Patch')
# Found good ('Packet Type', 'Network Segment', 'OS Version')
# Found good ('Packet Type', 'Network Segment', 'OS Version Minor')
# Found good ('Packet Type', 'Network Segment', 'OS Version Patch')
# Found good ('Packet Type', 'Network Segment', 'Device Brand')
# Found good ('Packet Type', 'Network Segment', 'Device Model')
# Found good ('Packet Type', 'Network Segment', 'Device Type')
# Found good ('Packet Type', 'Network Segment', 'Scale Packet Length')
# Time since start for 1900 combinations: 41.45 seconds
# Found good ('Packet Type', 'Firewall Logs', 'Browser Version')
# Found good ('Packet Type', 'Firewall Logs', 'Browser Minor')
# Found good ('Packet Type', 'Firewall Logs', 'Browser Patch')
# Found good ('Packet Type', 'Firewall Logs', 'OS Version')
# Found good ('Packet Type', 'Firewall Logs', 'OS Version Minor')
# Found good ('Packet Type', 'Firewall Logs', 'OS Version Patch')
# Found good ('Packet Type', 'Firewall Logs', 'Device Model')
# Found good ('Packet Type', 'Firewall Logs', 'Device Type')
# Found good ('Packet Type', 'Firewall Logs', 'Scale Packet Length')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'Browser Name')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'Browser Version')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'Browser Minor')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'Browser Patch')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'OS Version')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'OS Version Minor')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'OS Version Patch')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'Device Model')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'Device Type')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'Scale Packet Length')
# Found good ('Packet Type', 'Log Source', 'Browser Name')
# Found good ('Packet Type', 'Log Source', 'Browser Version')
# Found good ('Packet Type', 'Log Source', 'Browser Minor')
# Found good ('Packet Type', 'Log Source', 'Browser Patch')
# Found good ('Packet Type', 'Log Source', 'OS Version')
# Found good ('Packet Type', 'Log Source', 'OS Version Minor')
# Found good ('Packet Type', 'Log Source', 'OS Version Patch')
# Found good ('Packet Type', 'Log Source', 'Device Model')
# Found good ('Packet Type', 'Log Source', 'Device Type')
# Found good ('Packet Type', 'Log Source', 'Scale Packet Length')
# Found good ('Packet Type', 'Browser Name', 'Browser Version')
# Found good ('Packet Type', 'Browser Name', 'Browser Minor')
# Found good ('Packet Type', 'Browser Name', 'Browser Patch')
# Found good ('Packet Type', 'Browser Name', 'Browser Patch Minor')
# Found good ('Packet Type', 'Browser Name', 'OS Name')
# Found good ('Packet Type', 'Browser Name', 'OS Version')
# Found good ('Packet Type', 'Browser Name', 'OS Version Minor')
# Found good ('Packet Type', 'Browser Name', 'OS Version Patch')
# Found good ('Packet Type', 'Browser Name', 'OS Version Patch Minor')
# Found good ('Packet Type', 'Browser Name', 'Device Brand')
# Found good ('Packet Type', 'Browser Name', 'Device Model')
# Time since start for 2000 combinations: 43.11 seconds
# Found good ('Packet Type', 'Browser Name', 'Device Type')
# Found good ('Packet Type', 'Browser Name', 'Packet Bin')
# Found good ('Packet Type', 'Browser Name', 'Global Source IP')
# Found good ('Packet Type', 'Browser Name', 'Global Destination IP')
# Found good ('Packet Type', 'Browser Name', 'Is Proxy')
# Found good ('Packet Type', 'Browser Version', 'Browser Minor')
# Found good ('Packet Type', 'Browser Version', 'Browser Patch Minor')
# Found good ('Packet Type', 'Browser Version', 'OS Name')
# Found good ('Packet Type', 'Browser Version', 'OS Version Minor')
# Found good ('Packet Type', 'Browser Version', 'OS Version Patch')
# Found good ('Packet Type', 'Browser Version', 'OS Version Patch Minor')
# Found good ('Packet Type', 'Browser Version', 'Device Brand')
# Found good ('Packet Type', 'Browser Version', 'Device Model')
# Found good ('Packet Type', 'Browser Version', 'Device Type')
# Found good ('Packet Type', 'Browser Version', 'Packet Bin')
# Found good ('Packet Type', 'Browser Version', 'Global Source IP')
# Found good ('Packet Type', 'Browser Version', 'Global Destination IP')
# Found good ('Packet Type', 'Browser Version', 'Is Proxy')
# Found good ('Packet Type', 'Browser Minor', 'Browser Patch')
# Found good ('Packet Type', 'Browser Minor', 'Browser Patch Minor')
# Found good ('Packet Type', 'Browser Minor', 'OS Name')
# Found good ('Packet Type', 'Browser Minor', 'OS Version Minor')
# Found good ('Packet Type', 'Browser Minor', 'OS Version Patch')
# Found good ('Packet Type', 'Browser Minor', 'OS Version Patch Minor')
# Found good ('Packet Type', 'Browser Minor', 'Packet Bin')
# Found good ('Packet Type', 'Browser Minor', 'Global Source IP')
# Found good ('Packet Type', 'Browser Minor', 'Global Destination IP')
# Found good ('Packet Type', 'Browser Minor', 'Is Proxy')
# Found good ('Packet Type', 'Browser Patch', 'Browser Patch Minor')
# Found good ('Packet Type', 'Browser Patch', 'OS Name')
# Found good ('Packet Type', 'Browser Patch', 'OS Version Patch Minor')
# Found good ('Packet Type', 'Browser Patch', 'Device Brand')
# Found good ('Packet Type', 'Browser Patch', 'Device Model')
# Found good ('Packet Type', 'Browser Patch', 'Device Type')
# Found good ('Packet Type', 'Browser Patch', 'Packet Bin')
# Found good ('Packet Type', 'Browser Patch', 'Global Source IP')
# Found good ('Packet Type', 'Browser Patch', 'Global Destination IP')
# Found good ('Packet Type', 'Browser Patch', 'Is Proxy')
# Found good ('Packet Type', 'Browser Patch Minor', 'OS Version')
# Found good ('Packet Type', 'Browser Patch Minor', 'OS Version Minor')
# Found good ('Packet Type', 'Browser Patch Minor', 'OS Version Patch')
# Found good ('Packet Type', 'Browser Patch Minor', 'Device Model')
# Found good ('Packet Type', 'Browser Patch Minor', 'Device Type')
# Found good ('Packet Type', 'Browser Patch Minor', 'Scale Packet Length')
# Found good ('Packet Type', 'OS Name', 'OS Version')
# Found good ('Packet Type', 'OS Name', 'OS Version Minor')
# Found good ('Packet Type', 'OS Name', 'OS Version Patch')
# Found good ('Packet Type', 'OS Name', 'Packet Bin')
# Found good ('Packet Type', 'OS Version', 'OS Version Minor')
# Found good ('Packet Type', 'OS Version', 'OS Version Patch')
# Found good ('Packet Type', 'OS Version', 'OS Version Patch Minor')
# Found good ('Packet Type', 'OS Version', 'Device Brand')
# Found good ('Packet Type', 'OS Version', 'Device Model')
# Found good ('Packet Type', 'OS Version', 'Device Type')
# Found good ('Packet Type', 'OS Version', 'Packet Bin')
# Found good ('Packet Type', 'OS Version', 'Global Source IP')
# Found good ('Packet Type', 'OS Version', 'Global Destination IP')
# Time since start for 2100 combinations: 44.56 seconds
# Found good ('Packet Type', 'OS Version', 'Is Proxy')
# Found good ('Packet Type', 'OS Version Minor', 'OS Version Patch')
# Found good ('Packet Type', 'OS Version Minor', 'Device Brand')
# Found good ('Packet Type', 'OS Version Minor', 'Device Model')
# Found good ('Packet Type', 'OS Version Minor', 'Device Type')
# Found good ('Packet Type', 'OS Version Minor', 'Packet Bin')
# Found good ('Packet Type', 'OS Version Minor', 'Global Source IP')
# Found good ('Packet Type', 'OS Version Minor', 'Global Destination IP')
# Found good ('Packet Type', 'OS Version Minor', 'Is Proxy')
# Found good ('Packet Type', 'OS Version Patch', 'OS Version Patch Minor')
# Found good ('Packet Type', 'OS Version Patch', 'Device Brand')
# Found good ('Packet Type', 'OS Version Patch', 'Device Model')
# Found good ('Packet Type', 'OS Version Patch', 'Device Type')
# Found good ('Packet Type', 'OS Version Patch', 'Packet Bin')
# Found good ('Packet Type', 'OS Version Patch', 'Global Source IP')
# Found good ('Packet Type', 'OS Version Patch', 'Global Destination IP')
# Found good ('Packet Type', 'OS Version Patch', 'Is Proxy')
# Found good ('Packet Type', 'OS Version Patch Minor', 'Scale Packet Length')
# Found good ('Packet Type', 'Device Brand', 'Packet Bin')
# Found good ('Packet Type', 'Device Brand', 'Scale Packet Length')
# Found good ('Packet Type', 'Device Model', 'Packet Bin')
# Found good ('Packet Type', 'Device Model', 'Global Source IP')
# Found good ('Packet Type', 'Device Model', 'Global Destination IP')
# Found good ('Packet Type', 'Device Model', 'Is Proxy')
# Found good ('Packet Type', 'Device Type', 'Packet Bin')
# Found good ('Packet Type', 'Device Type', 'Global Source IP')
# Found good ('Packet Type', 'Device Type', 'Global Destination IP')
# Found good ('Packet Type', 'Device Type', 'Is Proxy')
# Found good ('Packet Type', 'Packet Bin', 'Scale Packet Length')
# Found good ('Packet Type', 'Scale Packet Length', 'Global Source IP')
# Found good ('Packet Type', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Packet Type', 'Scale Packet Length', 'Is Proxy')
# Found good ('Traffic Type', 'Malware Indicators', 'Browser Name')
# Found good ('Traffic Type', 'Malware Indicators', 'Browser Version')
# Found good ('Traffic Type', 'Malware Indicators', 'Browser Minor')
# Found good ('Traffic Type', 'Malware Indicators', 'Browser Patch')
# Found good ('Traffic Type', 'Malware Indicators', 'OS Name')
# Found good ('Traffic Type', 'Malware Indicators', 'OS Version')
# Found good ('Traffic Type', 'Malware Indicators', 'OS Version Minor')
# Found good ('Traffic Type', 'Malware Indicators', 'OS Version Patch')
# Time since start for 2200 combinations: 46.02 seconds
# Found good ('Traffic Type', 'Malware Indicators', 'Device Model')
# Found good ('Traffic Type', 'Malware Indicators', 'Device Type')
# Found good ('Traffic Type', 'Malware Indicators', 'Scale Packet Length')
# Found good ('Traffic Type', 'Alerts/Warnings', 'Browser Name')
# Found good ('Traffic Type', 'Alerts/Warnings', 'Browser Version')
# Found good ('Traffic Type', 'Alerts/Warnings', 'Browser Minor')
# Found good ('Traffic Type', 'Alerts/Warnings', 'Browser Patch')
# Found good ('Traffic Type', 'Alerts/Warnings', 'OS Name')
# Found good ('Traffic Type', 'Alerts/Warnings', 'OS Version')
# Found good ('Traffic Type', 'Alerts/Warnings', 'OS Version Minor')
# Found good ('Traffic Type', 'Alerts/Warnings', 'OS Version Patch')
# Found good ('Traffic Type', 'Alerts/Warnings', 'Device Brand')
# Found good ('Traffic Type', 'Alerts/Warnings', 'Device Model')
# Found good ('Traffic Type', 'Alerts/Warnings', 'Device Type')
# Found good ('Traffic Type', 'Alerts/Warnings', 'Scale Packet Length')
# Found good ('Traffic Type', 'Attack Signature', 'Browser Name')
# Found good ('Traffic Type', 'Attack Signature', 'Browser Version')
# Found good ('Traffic Type', 'Attack Signature', 'Browser Minor')
# Found good ('Traffic Type', 'Attack Signature', 'Browser Patch')
# Found good ('Traffic Type', 'Attack Signature', 'OS Version')
# Found good ('Traffic Type', 'Attack Signature', 'OS Version Minor')
# Found good ('Traffic Type', 'Attack Signature', 'OS Version Patch')
# Found good ('Traffic Type', 'Attack Signature', 'Device Model')
# Found good ('Traffic Type', 'Attack Signature', 'Device Type')
# Found good ('Traffic Type', 'Attack Signature', 'Scale Packet Length')
# Found good ('Traffic Type', 'Action Taken', 'Browser Name')
# Time since start for 2300 combinations: 47.50 seconds
# Found good ('Traffic Type', 'Action Taken', 'Browser Version')
# Found good ('Traffic Type', 'Action Taken', 'Browser Minor')
# Found good ('Traffic Type', 'Action Taken', 'Browser Patch')
# Found good ('Traffic Type', 'Action Taken', 'OS Name')
# Found good ('Traffic Type', 'Action Taken', 'OS Version')
# Found good ('Traffic Type', 'Action Taken', 'OS Version Minor')
# Found good ('Traffic Type', 'Action Taken', 'OS Version Patch')
# Found good ('Traffic Type', 'Action Taken', 'Device Model')
# Found good ('Traffic Type', 'Action Taken', 'Device Type')
# Found good ('Traffic Type', 'Severity Level', 'Browser Name')
# Found good ('Traffic Type', 'Severity Level', 'Browser Version')
# Found good ('Traffic Type', 'Severity Level', 'Browser Minor')
# Found good ('Traffic Type', 'Severity Level', 'Browser Patch')
# Found good ('Traffic Type', 'Severity Level', 'OS Name')
# Found good ('Traffic Type', 'Severity Level', 'OS Version')
# Found good ('Traffic Type', 'Severity Level', 'OS Version Minor')
# Found good ('Traffic Type', 'Severity Level', 'OS Version Patch')
# Found good ('Traffic Type', 'Severity Level', 'Device Model')
# Found good ('Traffic Type', 'Severity Level', 'Device Type')
# Found good ('Traffic Type', 'Severity Level', 'Packet Bin')
# Found good ('Traffic Type', 'Network Segment', 'Browser Name')
# Found good ('Traffic Type', 'Network Segment', 'Browser Version')
# Found good ('Traffic Type', 'Network Segment', 'Browser Minor')
# Found good ('Traffic Type', 'Network Segment', 'Browser Patch')
# Found good ('Traffic Type', 'Network Segment', 'OS Name')
# Found good ('Traffic Type', 'Network Segment', 'OS Version')
# Found good ('Traffic Type', 'Network Segment', 'OS Version Minor')
# Found good ('Traffic Type', 'Network Segment', 'OS Version Patch')
# Found good ('Traffic Type', 'Network Segment', 'Device Model')
# Found good ('Traffic Type', 'Network Segment', 'Device Type')
# Found good ('Traffic Type', 'Firewall Logs', 'Browser Name')
# Found good ('Traffic Type', 'Firewall Logs', 'Browser Version')
# Found good ('Traffic Type', 'Firewall Logs', 'Browser Minor')
# Found good ('Traffic Type', 'Firewall Logs', 'Browser Patch')
# Found good ('Traffic Type', 'Firewall Logs', 'OS Name')
# Found good ('Traffic Type', 'Firewall Logs', 'OS Version')
# Time since start for 2400 combinations: 49.04 seconds
# Found good ('Traffic Type', 'Firewall Logs', 'OS Version Minor')
# Found good ('Traffic Type', 'Firewall Logs', 'OS Version Patch')
# Found good ('Traffic Type', 'Firewall Logs', 'Device Model')
# Found good ('Traffic Type', 'Firewall Logs', 'Device Type')
# Found good ('Traffic Type', 'Firewall Logs', 'Scale Packet Length')
# Found good ('Traffic Type', 'IDS/IPS Alerts', 'Browser Name')
# Found good ('Traffic Type', 'IDS/IPS Alerts', 'Browser Version')
# Found good ('Traffic Type', 'IDS/IPS Alerts', 'Browser Minor')
# Found good ('Traffic Type', 'IDS/IPS Alerts', 'Browser Patch')
# Found good ('Traffic Type', 'IDS/IPS Alerts', 'OS Version')
# Found good ('Traffic Type', 'IDS/IPS Alerts', 'OS Version Minor')
# Found good ('Traffic Type', 'IDS/IPS Alerts', 'OS Version Patch')
# Found good ('Traffic Type', 'IDS/IPS Alerts', 'Device Model')
# Found good ('Traffic Type', 'IDS/IPS Alerts', 'Device Type')
# Found good ('Traffic Type', 'IDS/IPS Alerts', 'Scale Packet Length')
# Found good ('Traffic Type', 'Log Source', 'Browser Name')
# Found good ('Traffic Type', 'Log Source', 'Browser Version')
# Found good ('Traffic Type', 'Log Source', 'Browser Minor')
# Found good ('Traffic Type', 'Log Source', 'Browser Patch')
# Found good ('Traffic Type', 'Log Source', 'OS Version')
# Found good ('Traffic Type', 'Log Source', 'OS Version Minor')
# Found good ('Traffic Type', 'Log Source', 'OS Version Patch')
# Found good ('Traffic Type', 'Log Source', 'Device Model')
# Found good ('Traffic Type', 'Log Source', 'Device Type')
# Found good ('Traffic Type', 'Log Source', 'Scale Packet Length')
# Found good ('Traffic Type', 'Browser Name', 'Browser Version')
# Found good ('Traffic Type', 'Browser Name', 'Browser Minor')
# Found good ('Traffic Type', 'Browser Name', 'Browser Patch')
# Found good ('Traffic Type', 'Browser Name', 'OS Name')
# Found good ('Traffic Type', 'Browser Name', 'OS Version')
# Found good ('Traffic Type', 'Browser Name', 'OS Version Minor')
# Found good ('Traffic Type', 'Browser Name', 'OS Version Patch')
# Found good ('Traffic Type', 'Browser Name', 'Device Brand')
# Found good ('Traffic Type', 'Browser Name', 'Device Model')
# Found good ('Traffic Type', 'Browser Name', 'Device Type')
# Found good ('Traffic Type', 'Browser Name', 'Packet Bin')
# Found good ('Traffic Type', 'Browser Name', 'Global Source IP')
# Found good ('Traffic Type', 'Browser Name', 'Global Destination IP')
# Found good ('Traffic Type', 'Browser Name', 'Is Proxy')
# Found good ('Traffic Type', 'Browser Version', 'Browser Minor')
# Found good ('Traffic Type', 'Browser Version', 'Browser Patch Minor')
# Found good ('Traffic Type', 'Browser Version', 'OS Name')
# Found good ('Traffic Type', 'Browser Version', 'OS Version Patch Minor')
# Found good ('Traffic Type', 'Browser Version', 'Device Brand')
# Found good ('Traffic Type', 'Browser Version', 'Device Model')
# Found good ('Traffic Type', 'Browser Version', 'Device Type')
# Found good ('Traffic Type', 'Browser Version', 'Packet Bin')
# Found good ('Traffic Type', 'Browser Version', 'Global Source IP')
# Found good ('Traffic Type', 'Browser Version', 'Global Destination IP')
# Found good ('Traffic Type', 'Browser Version', 'Is Proxy')
# Found good ('Traffic Type', 'Browser Minor', 'Browser Patch')
# Found good ('Traffic Type', 'Browser Minor', 'Browser Patch Minor')
# Found good ('Traffic Type', 'Browser Minor', 'OS Name')
# Found good ('Traffic Type', 'Browser Minor', 'OS Version Minor')
# Found good ('Traffic Type', 'Browser Minor', 'OS Version Patch')
# Found good ('Traffic Type', 'Browser Minor', 'OS Version Patch Minor')
# Time since start for 2500 combinations: 50.34 seconds
# Found good ('Traffic Type', 'Browser Minor', 'Packet Bin')
# Found good ('Traffic Type', 'Browser Minor', 'Global Source IP')
# Found good ('Traffic Type', 'Browser Minor', 'Global Destination IP')
# Found good ('Traffic Type', 'Browser Minor', 'Is Proxy')
# Found good ('Traffic Type', 'Browser Patch', 'Browser Patch Minor')
# Found good ('Traffic Type', 'Browser Patch', 'OS Name')
# Found good ('Traffic Type', 'Browser Patch', 'OS Version Patch Minor')
# Found good ('Traffic Type', 'Browser Patch', 'Device Brand')
# Found good ('Traffic Type', 'Browser Patch', 'Device Model')
# Found good ('Traffic Type', 'Browser Patch', 'Device Type')
# Found good ('Traffic Type', 'Browser Patch', 'Packet Bin')
# Found good ('Traffic Type', 'Browser Patch', 'Global Source IP')
# Found good ('Traffic Type', 'Browser Patch', 'Global Destination IP')
# Found good ('Traffic Type', 'Browser Patch', 'Is Proxy')
# Found good ('Traffic Type', 'Browser Patch Minor', 'OS Version')
# Found good ('Traffic Type', 'Browser Patch Minor', 'OS Version Minor')
# Found good ('Traffic Type', 'Browser Patch Minor', 'OS Version Patch')
# Found good ('Traffic Type', 'Browser Patch Minor', 'Device Model')
# Found good ('Traffic Type', 'Browser Patch Minor', 'Device Type')
# Found good ('Traffic Type', 'Browser Patch Minor', 'Scale Packet Length')
# Found good ('Traffic Type', 'OS Name', 'OS Version')
# Found good ('Traffic Type', 'OS Name', 'OS Version Minor')
# Found good ('Traffic Type', 'OS Name', 'OS Version Patch')
# Found good ('Traffic Type', 'OS Name', 'Device Brand')
# Found good ('Traffic Type', 'OS Name', 'Device Model')
# Found good ('Traffic Type', 'OS Name', 'Device Type')
# Found good ('Traffic Type', 'OS Name', 'Packet Bin')
# Found good ('Traffic Type', 'OS Name', 'Global Source IP')
# Found good ('Traffic Type', 'OS Name', 'Global Destination IP')
# Found good ('Traffic Type', 'OS Version', 'OS Version Minor')
# Found good ('Traffic Type', 'OS Version', 'OS Version Patch')
# Found good ('Traffic Type', 'OS Version', 'OS Version Patch Minor')
# Found good ('Traffic Type', 'OS Version', 'Device Brand')
# Found good ('Traffic Type', 'OS Version', 'Device Model')
# Found good ('Traffic Type', 'OS Version', 'Device Type')
# Found good ('Traffic Type', 'OS Version', 'Packet Bin')
# Found good ('Traffic Type', 'OS Version', 'Global Source IP')
# Found good ('Traffic Type', 'OS Version', 'Global Destination IP')
# Found good ('Traffic Type', 'OS Version', 'Is Proxy')
# Found good ('Traffic Type', 'OS Version Minor', 'OS Version Patch')
# Found good ('Traffic Type', 'OS Version Minor', 'OS Version Patch Minor')
# Found good ('Traffic Type', 'OS Version Minor', 'Device Brand')
# Found good ('Traffic Type', 'OS Version Minor', 'Device Model')
# Found good ('Traffic Type', 'OS Version Minor', 'Device Type')
# Found good ('Traffic Type', 'OS Version Minor', 'Packet Bin')
# Found good ('Traffic Type', 'OS Version Minor', 'Global Source IP')
# Found good ('Traffic Type', 'OS Version Minor', 'Global Destination IP')
# Found good ('Traffic Type', 'OS Version Minor', 'Is Proxy')
# Found good ('Traffic Type', 'OS Version Patch', 'OS Version Patch Minor')
# Found good ('Traffic Type', 'OS Version Patch', 'Device Brand')
# Found good ('Traffic Type', 'OS Version Patch', 'Device Model')
# Found good ('Traffic Type', 'OS Version Patch', 'Device Type')
# Found good ('Traffic Type', 'OS Version Patch', 'Packet Bin')
# Found good ('Traffic Type', 'OS Version Patch', 'Global Source IP')
# Found good ('Traffic Type', 'OS Version Patch', 'Global Destination IP')
# Found good ('Traffic Type', 'OS Version Patch', 'Is Proxy')
# Found good ('Traffic Type', 'OS Version Patch Minor', 'Device Model')
# Found good ('Traffic Type', 'OS Version Patch Minor', 'Device Type')
# Found good ('Traffic Type', 'OS Version Patch Minor', 'Scale Packet Length')
# Found good ('Traffic Type', 'Device Brand', 'Device Model')
# Time since start for 2600 combinations: 51.75 seconds
# Found good ('Traffic Type', 'Device Brand', 'Device Type')
# Found good ('Traffic Type', 'Device Model', 'Device Type')
# Found good ('Traffic Type', 'Device Model', 'Packet Bin')
# Found good ('Traffic Type', 'Device Model', 'Global Source IP')
# Found good ('Traffic Type', 'Device Model', 'Global Destination IP')
# Found good ('Traffic Type', 'Device Model', 'Is Proxy')
# Found good ('Traffic Type', 'Device Type', 'Packet Bin')
# Found good ('Traffic Type', 'Device Type', 'Global Source IP')
# Found good ('Traffic Type', 'Device Type', 'Global Destination IP')
# Found good ('Traffic Type', 'Device Type', 'Is Proxy')
# Found good ('Traffic Type', 'Packet Bin', 'Scale Packet Length')
# Found good ('Traffic Type', 'Scale Packet Length', 'Global Source IP')
# Found good ('Traffic Type', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Traffic Type', 'Scale Packet Length', 'Is Proxy')
# Found good ('Malware Indicators', 'Alerts/Warnings', 'Browser Name')
# Found good ('Malware Indicators', 'Alerts/Warnings', 'Browser Version')
# Found good ('Malware Indicators', 'Alerts/Warnings', 'Browser Minor')
# Found good ('Malware Indicators', 'Alerts/Warnings', 'Browser Patch')
# Found good ('Malware Indicators', 'Alerts/Warnings', 'OS Version')
# Found good ('Malware Indicators', 'Alerts/Warnings', 'OS Version Minor')
# Found good ('Malware Indicators', 'Alerts/Warnings', 'OS Version Patch')
# Found good ('Malware Indicators', 'Alerts/Warnings', 'Device Model')
# Found good ('Malware Indicators', 'Alerts/Warnings', 'Device Type')
# Found good ('Malware Indicators', 'Alerts/Warnings', 'Scale Packet Length')
# Time since start for 2700 combinations: 53.38 seconds
# Found good ('Malware Indicators', 'Attack Signature', 'Browser Name')
# Found good ('Malware Indicators', 'Attack Signature', 'Browser Version')
# Found good ('Malware Indicators', 'Attack Signature', 'Browser Minor')
# Found good ('Malware Indicators', 'Attack Signature', 'Browser Patch')
# Found good ('Malware Indicators', 'Attack Signature', 'OS Version')
# Found good ('Malware Indicators', 'Attack Signature', 'OS Version Minor')
# Found good ('Malware Indicators', 'Attack Signature', 'OS Version Patch')
# Found good ('Malware Indicators', 'Attack Signature', 'Scale Packet Length')
# Found good ('Malware Indicators', 'Action Taken', 'Browser Name')
# Found good ('Malware Indicators', 'Action Taken', 'Browser Version')
# Found good ('Malware Indicators', 'Action Taken', 'Browser Minor')
# Found good ('Malware Indicators', 'Action Taken', 'Browser Patch')
# Found good ('Malware Indicators', 'Action Taken', 'OS Name')
# Found good ('Malware Indicators', 'Action Taken', 'OS Version')
# Found good ('Malware Indicators', 'Action Taken', 'OS Version Minor')
# Found good ('Malware Indicators', 'Action Taken', 'OS Version Patch')
# Found good ('Malware Indicators', 'Action Taken', 'Device Model')
# Found good ('Malware Indicators', 'Action Taken', 'Device Type')
# Found good ('Malware Indicators', 'Action Taken', 'Scale Packet Length')
# Found good ('Malware Indicators', 'Severity Level', 'Browser Name')
# Found good ('Malware Indicators', 'Severity Level', 'Browser Version')
# Found good ('Malware Indicators', 'Severity Level', 'Browser Minor')
# Found good ('Malware Indicators', 'Severity Level', 'Browser Patch')
# Found good ('Malware Indicators', 'Severity Level', 'OS Version')
# Found good ('Malware Indicators', 'Severity Level', 'OS Version Minor')
# Found good ('Malware Indicators', 'Severity Level', 'OS Version Patch')
# Found good ('Malware Indicators', 'Severity Level', 'Device Model')
# Found good ('Malware Indicators', 'Severity Level', 'Device Type')
# Found good ('Malware Indicators', 'Severity Level', 'Scale Packet Length')
# Found good ('Malware Indicators', 'Network Segment', 'Browser Name')
# Found good ('Malware Indicators', 'Network Segment', 'Browser Version')
# Found good ('Malware Indicators', 'Network Segment', 'Browser Minor')
# Found good ('Malware Indicators', 'Network Segment', 'Browser Patch')
# Found good ('Malware Indicators', 'Network Segment', 'OS Version')
# Found good ('Malware Indicators', 'Network Segment', 'OS Version Minor')
# Found good ('Malware Indicators', 'Network Segment', 'OS Version Patch')
# Found good ('Malware Indicators', 'Network Segment', 'Scale Packet Length')
# Time since start for 2800 combinations: 54.51 seconds
# Found good ('Malware Indicators', 'Firewall Logs', 'Browser Name')
# Found good ('Malware Indicators', 'Firewall Logs', 'Browser Version')
# Found good ('Malware Indicators', 'Firewall Logs', 'Browser Minor')
# Found good ('Malware Indicators', 'Firewall Logs', 'Browser Patch')
# Found good ('Malware Indicators', 'Firewall Logs', 'OS Version')
# Found good ('Malware Indicators', 'Firewall Logs', 'OS Version Minor')
# Found good ('Malware Indicators', 'Firewall Logs', 'OS Version Patch')
# Found good ('Malware Indicators', 'Firewall Logs', 'Device Model')
# Found good ('Malware Indicators', 'Firewall Logs', 'Device Type')
# Found good ('Malware Indicators', 'Firewall Logs', 'Scale Packet Length')
# Found good ('Malware Indicators', 'IDS/IPS Alerts', 'Browser Name')
# Found good ('Malware Indicators', 'IDS/IPS Alerts', 'Browser Version')
# Found good ('Malware Indicators', 'IDS/IPS Alerts', 'Browser Minor')
# Found good ('Malware Indicators', 'IDS/IPS Alerts', 'Browser Patch')
# Found good ('Malware Indicators', 'IDS/IPS Alerts', 'OS Version')
# Found good ('Malware Indicators', 'IDS/IPS Alerts', 'OS Version Minor')
# Found good ('Malware Indicators', 'IDS/IPS Alerts', 'OS Version Patch')
# Found good ('Malware Indicators', 'IDS/IPS Alerts', 'Device Model')
# Found good ('Malware Indicators', 'IDS/IPS Alerts', 'Device Type')
# Found good ('Malware Indicators', 'IDS/IPS Alerts', 'Scale Packet Length')
# Found good ('Malware Indicators', 'Log Source', 'Browser Name')
# Found good ('Malware Indicators', 'Log Source', 'Browser Version')
# Found good ('Malware Indicators', 'Log Source', 'Browser Minor')
# Found good ('Malware Indicators', 'Log Source', 'Browser Patch')
# Found good ('Malware Indicators', 'Log Source', 'OS Version')
# Found good ('Malware Indicators', 'Log Source', 'OS Version Minor')
# Found good ('Malware Indicators', 'Log Source', 'Scale Packet Length')
# Found good ('Malware Indicators', 'Browser Name', 'Browser Version')
# Found good ('Malware Indicators', 'Browser Name', 'Browser Minor')
# Found good ('Malware Indicators', 'Browser Name', 'Browser Patch')
# Found good ('Malware Indicators', 'Browser Name', 'Browser Patch Minor')
# Found good ('Malware Indicators', 'Browser Name', 'OS Name')
# Found good ('Malware Indicators', 'Browser Name', 'OS Version')
# Found good ('Malware Indicators', 'Browser Name', 'OS Version Minor')
# Found good ('Malware Indicators', 'Browser Name', 'OS Version Patch')
# Found good ('Malware Indicators', 'Browser Name', 'OS Version Patch Minor')
# Found good ('Malware Indicators', 'Browser Name', 'Device Brand')
# Found good ('Malware Indicators', 'Browser Name', 'Device Model')
# Time since start for 2900 combinations: 56.10 seconds
# Found good ('Malware Indicators', 'Browser Name', 'Device Type')
# Found good ('Malware Indicators', 'Browser Name', 'Packet Bin')
# Found good ('Malware Indicators', 'Browser Name', 'Global Source IP')
# Found good ('Malware Indicators', 'Browser Name', 'Global Destination IP')
# Found good ('Malware Indicators', 'Browser Name', 'Is Proxy')
# Found good ('Malware Indicators', 'Browser Version', 'Browser Minor')
# Found good ('Malware Indicators', 'Browser Version', 'Browser Patch Minor')
# Found good ('Malware Indicators', 'Browser Version', 'OS Name')
# Found good ('Malware Indicators', 'Browser Version', 'OS Version Minor')
# Found good ('Malware Indicators', 'Browser Version', 'OS Version Patch')
# Found good ('Malware Indicators', 'Browser Version', 'OS Version Patch Minor')
# Found good ('Malware Indicators', 'Browser Version', 'Device Brand')
# Found good ('Malware Indicators', 'Browser Version', 'Device Model')
# Found good ('Malware Indicators', 'Browser Version', 'Device Type')
# Found good ('Malware Indicators', 'Browser Version', 'Packet Bin')
# Found good ('Malware Indicators', 'Browser Version', 'Global Source IP')
# Found good ('Malware Indicators', 'Browser Version', 'Global Destination IP')
# Found good ('Malware Indicators', 'Browser Version', 'Is Proxy')
# Found good ('Malware Indicators', 'Browser Minor', 'Browser Patch')
# Found good ('Malware Indicators', 'Browser Minor', 'Browser Patch Minor')
# Found good ('Malware Indicators', 'Browser Minor', 'OS Name')
# Found good ('Malware Indicators', 'Browser Minor', 'OS Version Minor')
# Found good ('Malware Indicators', 'Browser Minor', 'OS Version Patch')
# Found good ('Malware Indicators', 'Browser Minor', 'OS Version Patch Minor')
# Found good ('Malware Indicators', 'Browser Minor', 'Packet Bin')
# Found good ('Malware Indicators', 'Browser Minor', 'Global Source IP')
# Found good ('Malware Indicators', 'Browser Minor', 'Global Destination IP')
# Found good ('Malware Indicators', 'Browser Minor', 'Is Proxy')
# Found good ('Malware Indicators', 'Browser Patch', 'Browser Patch Minor')
# Found good ('Malware Indicators', 'Browser Patch', 'OS Name')
# Found good ('Malware Indicators', 'Browser Patch', 'OS Version Patch Minor')
# Found good ('Malware Indicators', 'Browser Patch', 'Device Brand')
# Found good ('Malware Indicators', 'Browser Patch', 'Device Model')
# Found good ('Malware Indicators', 'Browser Patch', 'Device Type')
# Found good ('Malware Indicators', 'Browser Patch', 'Packet Bin')
# Found good ('Malware Indicators', 'Browser Patch', 'Global Source IP')
# Found good ('Malware Indicators', 'Browser Patch', 'Global Destination IP')
# Found good ('Malware Indicators', 'Browser Patch', 'Is Proxy')
# Found good ('Malware Indicators', 'Browser Patch Minor', 'OS Version')
# Found good ('Malware Indicators', 'Browser Patch Minor', 'OS Version Minor')
# Found good ('Malware Indicators', 'Browser Patch Minor', 'OS Version Patch')
# Found good ('Malware Indicators', 'Browser Patch Minor', 'Device Model')
# Found good ('Malware Indicators', 'Browser Patch Minor', 'Device Type')
# ...
# Found good ('Browser Patch', 'Device Model', 'Global Destination IP')
# Found good ('Browser Patch', 'Device Model', 'Is Proxy')
# Found good ('Browser Patch', 'Device Type', 'Packet Bin')
# Found good ('Browser Patch', 'Device Type', 'Global Source IP')
# Found good ('Browser Patch', 'Device Type', 'Global Destination IP')
# Found good ('Browser Patch', 'Device Type', 'Is Proxy')
# Found good ('Browser Patch', 'Packet Bin', 'Global Source IP')
# Found good ('Browser Patch', 'Packet Bin', 'Global Destination IP')
# Found good ('Browser Patch', 'Packet Bin', 'Is Proxy')
# Found good ('Browser Patch', 'Global Source IP', 'Is Proxy')
# Found good ('Browser Patch', 'Global Destination IP', 'Is Proxy')
# Found good ('Browser Patch Minor', 'OS Name', 'OS Version')
# Found good ('Browser Patch Minor', 'OS Name', 'OS Version Minor')
# Found good ('Browser Patch Minor', 'OS Name', 'OS Version Patch')
# Found good ('Browser Patch Minor', 'OS Name', 'Global Source IP')
# Found good ('Browser Patch Minor', 'OS Name', 'Global Destination IP')
# Found good ('Browser Patch Minor', 'OS Version', 'OS Version Minor')
# Found good ('Browser Patch Minor', 'OS Version', 'OS Version Patch')
# Found good ('Browser Patch Minor', 'OS Version', 'OS Version Patch Minor')
# Found good ('Browser Patch Minor', 'OS Version', 'Device Brand')
# Found good ('Browser Patch Minor', 'OS Version', 'Device Model')
# Found good ('Browser Patch Minor', 'OS Version', 'Device Type')
# Found good ('Browser Patch Minor', 'OS Version', 'Packet Bin')
# Time since start for 6600 combinations: 122.85 seconds
# Found good ('Browser Patch Minor', 'OS Version', 'Global Source IP')
# Found good ('Browser Patch Minor', 'OS Version', 'Global Destination IP')
# Found good ('Browser Patch Minor', 'OS Version', 'Is Proxy')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'OS Version Patch')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'OS Version Patch Minor')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'Device Brand')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'Device Model')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'Device Type')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'Packet Bin')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'Global Source IP')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'Global Destination IP')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'Is Proxy')
# Found good ('Browser Patch Minor', 'OS Version Patch', 'OS Version Patch Minor')
# Found good ('Browser Patch Minor', 'OS Version Patch', 'Device Brand')
# Found good ('Browser Patch Minor', 'OS Version Patch', 'Device Model')
# Found good ('Browser Patch Minor', 'OS Version Patch', 'Device Type')
# Found good ('Browser Patch Minor', 'OS Version Patch', 'Packet Bin')
# Found good ('Browser Patch Minor', 'OS Version Patch', 'Global Source IP')
# Found good ('Browser Patch Minor', 'OS Version Patch', 'Global Destination IP')
# Found good ('Browser Patch Minor', 'OS Version Patch', 'Is Proxy')
# Found good ('Browser Patch Minor', 'OS Version Patch Minor', 'Scale Packet Length')
# Found good ('Browser Patch Minor', 'Device Model', 'Global Source IP')
# Found good ('Browser Patch Minor', 'Device Model', 'Global Destination IP')
# Found good ('Browser Patch Minor', 'Device Type', 'Global Source IP')
# Found good ('Browser Patch Minor', 'Device Type', 'Global Destination IP')
# Found good ('Browser Patch Minor', 'Packet Bin', 'Scale Packet Length')
# Found good ('Browser Patch Minor', 'Scale Packet Length', 'Global Source IP')
# Found good ('Browser Patch Minor', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Browser Patch Minor', 'Scale Packet Length', 'Is Proxy')
# Found good ('Browser Patch Minor', 'Global Source IP', 'Global Destination IP')
# Found good ('OS Name', 'OS Version', 'OS Version Minor')
# Found good ('OS Name', 'OS Version', 'OS Version Patch')
# Found good ('OS Name', 'OS Version', 'OS Version Patch Minor')
# Found good ('OS Name', 'OS Version', 'Device Brand')
# Found good ('OS Name', 'OS Version', 'Device Model')
# Found good ('OS Name', 'OS Version', 'Device Type')
# Found good ('OS Name', 'OS Version', 'Packet Bin')
# Found good ('OS Name', 'OS Version', 'Global Source IP')
# Found good ('OS Name', 'OS Version', 'Global Destination IP')
# Found good ('OS Name', 'OS Version', 'Is Proxy')
# Found good ('OS Name', 'OS Version Minor', 'OS Version Patch')
# Time since start for 6700 combinations: 124.60 seconds
# Found good ('OS Name', 'OS Version Minor', 'Device Model')
# Found good ('OS Name', 'OS Version Minor', 'Device Type')
# Found good ('OS Name', 'OS Version Minor', 'Packet Bin')
# Found good ('OS Name', 'OS Version Minor', 'Global Source IP')
# Found good ('OS Name', 'OS Version Minor', 'Global Destination IP')
# Found good ('OS Name', 'OS Version Minor', 'Is Proxy')
# Found good ('OS Name', 'OS Version Patch', 'OS Version Patch Minor')
# Found good ('OS Name', 'OS Version Patch', 'Device Brand')
# Found good ('OS Name', 'OS Version Patch', 'Device Model')
# Found good ('OS Name', 'OS Version Patch', 'Device Type')
# Found good ('OS Name', 'OS Version Patch', 'Packet Bin')
# Found good ('OS Name', 'OS Version Patch', 'Global Source IP')
# Found good ('OS Name', 'OS Version Patch', 'Global Destination IP')
# Found good ('OS Name', 'OS Version Patch', 'Is Proxy')
# Found good ('OS Name', 'OS Version Patch Minor', 'Scale Packet Length')
# Found good ('OS Name', 'Device Brand', 'Scale Packet Length')
# Found good ('OS Name', 'Device Model', 'Packet Bin')
# Found good ('OS Name', 'Device Model', 'Global Destination IP')
# Found good ('OS Name', 'Device Type', 'Packet Bin')
# Found good ('OS Name', 'Device Type', 'Global Destination IP')
# Found good ('OS Name', 'Packet Bin', 'Scale Packet Length')
# Found good ('OS Name', 'Packet Bin', 'Global Source IP')
# Found good ('OS Name', 'Scale Packet Length', 'Global Source IP')
# Found good ('OS Name', 'Scale Packet Length', 'Global Destination IP')
# Found good ('OS Name', 'Global Source IP', 'Global Destination IP')
# Found good ('OS Version', 'OS Version Minor', 'OS Version Patch')
# Found good ('OS Version', 'OS Version Minor', 'OS Version Patch Minor')
# Found good ('OS Version', 'OS Version Minor', 'Device Brand')
# Found good ('OS Version', 'OS Version Minor', 'Device Model')
# Found good ('OS Version', 'OS Version Minor', 'Device Type')
# Found good ('OS Version', 'OS Version Minor', 'Packet Bin')
# Found good ('OS Version', 'OS Version Minor', 'Global Source IP')
# Found good ('OS Version', 'OS Version Minor', 'Global Destination IP')
# Found good ('OS Version', 'OS Version Minor', 'Is Proxy')
# Found good ('OS Version', 'OS Version Patch', 'OS Version Patch Minor')
# Found good ('OS Version', 'OS Version Patch', 'Device Brand')
# Found good ('OS Version', 'OS Version Patch', 'Device Model')
# Found good ('OS Version', 'OS Version Patch', 'Device Type')
# Found good ('OS Version', 'OS Version Patch', 'Packet Bin')
# Found good ('OS Version', 'OS Version Patch', 'Global Source IP')
# Found good ('OS Version', 'OS Version Patch', 'Global Destination IP')
# Found good ('OS Version', 'OS Version Patch', 'Is Proxy')
# Found good ('OS Version', 'OS Version Patch Minor', 'Device Brand')
# Found good ('OS Version', 'OS Version Patch Minor', 'Device Model')
# Time since start for 6800 combinations: 126.38 seconds
# Found good ('OS Version', 'OS Version Patch Minor', 'Device Type')
# Found good ('OS Version', 'OS Version Patch Minor', 'Packet Bin')
# Found good ('OS Version', 'OS Version Patch Minor', 'Global Source IP')
# Found good ('OS Version', 'OS Version Patch Minor', 'Global Destination IP')
# Found good ('OS Version', 'OS Version Patch Minor', 'Is Proxy')
# Found good ('OS Version', 'Device Brand', 'Device Model')
# Found good ('OS Version', 'Device Brand', 'Device Type')
# Found good ('OS Version', 'Device Brand', 'Packet Bin')
# Found good ('OS Version', 'Device Brand', 'Global Source IP')
# Found good ('OS Version', 'Device Brand', 'Global Destination IP')
# Found good ('OS Version', 'Device Brand', 'Is Proxy')
# Found good ('OS Version', 'Device Model', 'Device Type')
# Found good ('OS Version', 'Device Model', 'Packet Bin')
# Found good ('OS Version', 'Device Model', 'Global Source IP')
# Found good ('OS Version', 'Device Model', 'Global Destination IP')
# Found good ('OS Version', 'Device Model', 'Is Proxy')
# Found good ('OS Version', 'Device Type', 'Packet Bin')
# Found good ('OS Version', 'Device Type', 'Global Source IP')
# Found good ('OS Version', 'Device Type', 'Global Destination IP')
# Found good ('OS Version', 'Device Type', 'Is Proxy')
# Found good ('OS Version', 'Packet Bin', 'Global Source IP')
# Found good ('OS Version', 'Packet Bin', 'Global Destination IP')
# Found good ('OS Version', 'Packet Bin', 'Is Proxy')
# Found good ('OS Version', 'Global Source IP', 'Global Destination IP')
# Found good ('OS Version', 'Global Source IP', 'Is Proxy')
# Found good ('OS Version', 'Global Destination IP', 'Is Proxy')
# Found good ('OS Version Minor', 'OS Version Patch', 'OS Version Patch Minor')
# Found good ('OS Version Minor', 'OS Version Patch', 'Device Brand')
# Found good ('OS Version Minor', 'OS Version Patch', 'Device Model')
# Found good ('OS Version Minor', 'OS Version Patch', 'Device Type')
# Found good ('OS Version Minor', 'OS Version Patch', 'Packet Bin')
# Found good ('OS Version Minor', 'OS Version Patch', 'Global Source IP')
# Found good ('OS Version Minor', 'OS Version Patch', 'Global Destination IP')
# Found good ('OS Version Minor', 'OS Version Patch', 'Is Proxy')
# Found good ('OS Version Minor', 'OS Version Patch Minor', 'Device Brand')
# Found good ('OS Version Minor', 'OS Version Patch Minor', 'Device Model')
# Found good ('OS Version Minor', 'OS Version Patch Minor', 'Device Type')
# Found good ('OS Version Minor', 'OS Version Patch Minor', 'Packet Bin')
# Found good ('OS Version Minor', 'OS Version Patch Minor', 'Global Source IP')
# Found good ('OS Version Minor', 'OS Version Patch Minor', 'Global Destination IP')
# Found good ('OS Version Minor', 'Device Brand', 'Device Model')
# Found good ('OS Version Minor', 'Device Brand', 'Device Type')
# Found good ('OS Version Minor', 'Device Brand', 'Packet Bin')
# Found good ('OS Version Minor', 'Device Brand', 'Global Source IP')
# Found good ('OS Version Minor', 'Device Brand', 'Global Destination IP')
# Found good ('OS Version Minor', 'Device Brand', 'Is Proxy')
# Found good ('OS Version Minor', 'Device Model', 'Device Type')
# Found good ('OS Version Minor', 'Device Model', 'Packet Bin')
# Found good ('OS Version Minor', 'Device Model', 'Global Source IP')
# Found good ('OS Version Minor', 'Device Model', 'Global Destination IP')
# Found good ('OS Version Minor', 'Device Model', 'Is Proxy')
# Found good ('OS Version Minor', 'Device Type', 'Packet Bin')
# Found good ('OS Version Minor', 'Device Type', 'Global Source IP')
# Found good ('OS Version Minor', 'Device Type', 'Global Destination IP')
# Found good ('OS Version Minor', 'Device Type', 'Is Proxy')
# Time since start for 6900 combinations: 128.23 seconds
# Found good ('OS Version Minor', 'Packet Bin', 'Global Source IP')
# Found good ('OS Version Minor', 'Packet Bin', 'Global Destination IP')
# Found good ('OS Version Minor', 'Packet Bin', 'Is Proxy')
# Found good ('OS Version Minor', 'Global Source IP', 'Global Destination IP')
# Found good ('OS Version Minor', 'Global Source IP', 'Is Proxy')
# Found good ('OS Version Minor', 'Global Destination IP', 'Is Proxy')
# Found good ('OS Version Patch', 'OS Version Patch Minor', 'Device Brand')
# Found good ('OS Version Patch', 'OS Version Patch Minor', 'Device Model')
# Found good ('OS Version Patch', 'OS Version Patch Minor', 'Device Type')
# Found good ('OS Version Patch', 'OS Version Patch Minor', 'Packet Bin')
# Found good ('OS Version Patch', 'OS Version Patch Minor', 'Global Source IP')
# Found good ('OS Version Patch', 'OS Version Patch Minor', 'Global Destination IP')
# Found good ('OS Version Patch', 'OS Version Patch Minor', 'Is Proxy')
# Found good ('OS Version Patch', 'Device Brand', 'Device Model')
# Found good ('OS Version Patch', 'Device Brand', 'Device Type')
# Found good ('OS Version Patch', 'Device Brand', 'Packet Bin')
# Found good ('OS Version Patch', 'Device Brand', 'Global Source IP')
# Found good ('OS Version Patch', 'Device Brand', 'Global Destination IP')
# Found good ('OS Version Patch', 'Device Brand', 'Is Proxy')
# Found good ('OS Version Patch', 'Device Model', 'Device Type')
# Found good ('OS Version Patch', 'Device Model', 'Packet Bin')
# Found good ('OS Version Patch', 'Device Model', 'Global Source IP')
# Found good ('OS Version Patch', 'Device Model', 'Global Destination IP')
# Found good ('OS Version Patch', 'Device Model', 'Is Proxy')
# Found good ('OS Version Patch', 'Device Type', 'Packet Bin')
# Found good ('OS Version Patch', 'Device Type', 'Global Source IP')
# Found good ('OS Version Patch', 'Device Type', 'Global Destination IP')
# Found good ('OS Version Patch', 'Device Type', 'Is Proxy')
# Found good ('OS Version Patch', 'Packet Bin', 'Global Source IP')
# Found good ('OS Version Patch', 'Packet Bin', 'Global Destination IP')
# Found good ('OS Version Patch', 'Packet Bin', 'Is Proxy')
# Found good ('OS Version Patch', 'Global Source IP', 'Global Destination IP')
# Found good ('OS Version Patch', 'Global Source IP', 'Is Proxy')
# Found good ('OS Version Patch', 'Global Destination IP', 'Is Proxy')
# Found good ('OS Version Patch Minor', 'Device Brand', 'Scale Packet Length')
# Found good ('OS Version Patch Minor', 'Device Model', 'Global Source IP')
# Found good ('OS Version Patch Minor', 'Device Model', 'Global Destination IP')
# Found good ('OS Version Patch Minor', 'Device Type', 'Global Source IP')
# Found good ('OS Version Patch Minor', 'Device Type', 'Global Destination IP')
# Found good ('OS Version Patch Minor', 'Packet Bin', 'Scale Packet Length')
# Time since start for 7000 combinations: 130.09 seconds
# Found good ('OS Version Patch Minor', 'Scale Packet Length', 'Global Source IP')
# Found good ('OS Version Patch Minor', 'Scale Packet Length', 'Global Destination IP')
# Found good ('OS Version Patch Minor', 'Scale Packet Length', 'Is Proxy')
# Found good ('OS Version Patch Minor', 'Global Source IP', 'Global Destination IP')
# Found good ('Device Brand', 'Device Model', 'Global Source IP')
# Found good ('Device Brand', 'Device Model', 'Global Destination IP')
# Found good ('Device Brand', 'Device Type', 'Global Source IP')
# Found good ('Device Brand', 'Device Type', 'Global Destination IP')
# Found good ('Device Brand', 'Packet Bin', 'Scale Packet Length')
# Found good ('Device Brand', 'Scale Packet Length', 'Global Source IP')
# Found good ('Device Brand', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Device Brand', 'Scale Packet Length', 'Is Proxy')
# Found good ('Device Brand', 'Global Source IP', 'Global Destination IP')
# Found good ('Device Model', 'Device Type', 'Global Source IP')
# Found good ('Device Model', 'Device Type', 'Global Destination IP')
# Found good ('Device Model', 'Packet Bin', 'Global Source IP')
# Found good ('Device Model', 'Packet Bin', 'Global Destination IP')
# Found good ('Device Model', 'Packet Bin', 'Is Proxy')
# Found good ('Device Model', 'Global Source IP', 'Global Destination IP')
# Found good ('Device Model', 'Global Source IP', 'Is Proxy')
# Found good ('Device Model', 'Global Destination IP', 'Is Proxy')
# Found good ('Device Type', 'Packet Bin', 'Global Source IP')
# Found good ('Device Type', 'Packet Bin', 'Global Destination IP')
# Found good ('Device Type', 'Packet Bin', 'Is Proxy')
# Time since start for 7100 combinations: 132.09 seconds
# Found good ('Device Type', 'Global Source IP', 'Global Destination IP')
# Found good ('Device Type', 'Global Source IP', 'Is Proxy')
# Found good ('Device Type', 'Global Destination IP', 'Is Proxy')
# Found good ('Packet Bin', 'Scale Packet Length', 'Global Source IP')
# Found good ('Packet Bin', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Packet Bin', 'Scale Packet Length', 'Is Proxy')
# Found good ('Scale Packet Length', 'Global Source IP', 'Global Destination IP')
# Found good ('Scale Packet Length', 'Global Source IP', 'Is Proxy')
# Found good ('Scale Packet Length', 'Global Destination IP', 'Is Proxy')

# %%
main_features = combinations_wo_date_df.iloc[:,0:2].value_counts()
main_features
# Out:
# Feature 1            Feature 2
# Protocol             Browser Name             16
# Packet Type          Browser Name             16
# Malware Indicators   Browser Name             16
# Severity Level       Browser Name             16
# Traffic Type         Browser Name             14
#                                               ..
# Device Brand         Packet Bin                1
#                      Global Source IP          1
# Device Model         Global Destination IP     1
# Device Type          Global Destination IP     1
# Scale Packet Length  Global Destination IP     1
# Name: count, Length: 367, dtype: int64

# %% [markdown]
# Same idea with Browser and device information.

# %%
relaunch = ""
while relaunch.lower() not in ["y","n"]:
    relaunch = input("Do you want to relaunch the analysis to find good combinations without device features? (y/n) ")
if relaunch.lower() == "y":
    data_wo_device = cleaned_data.copy().drop(columns=["Day", "Month", "Year","Hour","Minute", "Second","IsWeekend","DayOfWeek",
                                                     "Browser Name", "Browser Version", "Browser Minor","Browser Patch", "Browser Patch Minor",
                                                     "OS Name", "OS Version", "OS Version Minor", "OS Version Patch", "OS Version Patch Minor",
                                                     "Device Brand", "Device Model", "Device Type"])
    col_combinations = [col for col in data_wo_device.columns if col != "Attack Type"]
    col_combinations = list(combinations(col_combinations,3))

    nb_rows=data_wo_device.shape[0]
    good_combinations = []
    start_time = time.monotonic()
    for i,combination in enumerate(col_combinations):
        columns = [col for col in combination]+["Attack Type"]
        temp_data = data_wo_device[columns]
        temp_data = temp_data.pivot_table(
            index=combination,  
            columns="Attack Type",
            aggfunc="count",
            fill_value=0
        )
        temp_data["Total"]= temp_data.sum(axis=1)
        percentage_data = temp_data[["DDoS","Malware", "Intrusion"]].div(temp_data["Total"], axis=0)
        percentage_data = percentage_data.max(axis=1) - percentage_data.min(axis=1)
        stats = percentage_data.describe()
        if stats.loc["25%"] > 0.02 and stats.loc["75%"] < 0.99:
            print(f"Found good {combination}")
            output = [feature for feature in combination]
            output.extend([f"%.4f" % stats.loc[x] for x in stats.index])
            good_combinations.append(output)
        if i%100==0 and i!=0:
            print(f"Time since start for {i:d} combinations: {time.monotonic() - start_time:.2f} seconds")
    print(f"Total time: {time.monotonic() - start_time} seconds")
    combinations_wo_device_df = pd.DataFrame(good_combinations, columns=["Feature 1", "Feature 2", "Feature 3", 'count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'])
    combinations_wo_device_df.to_csv(path.joinpath("combinations_wo_device.csv"), index=False)
else:
    combinations_wo_device_df = pd.read_csv(path.joinpath("combinations_wo_device.csv"))
# Out:
# Time since start for 100 combinations: 2.69 seconds
# Time since start for 200 combinations: 5.56 seconds
# Time since start for 300 combinations: 8.17 seconds
# Time since start for 400 combinations: 10.90 seconds
# Found good ('Protocol', 'Packet Type', 'Scale Packet Length')
# Found good ('Protocol', 'Malware Indicators', 'Scale Packet Length')
# Time since start for 500 combinations: 12.75 seconds
# Found good ('Protocol', 'Alerts/Warnings', 'Scale Packet Length')
# Found good ('Protocol', 'Attack Signature', 'Scale Packet Length')
# Found good ('Protocol', 'Action Taken', 'Scale Packet Length')
# Found good ('Protocol', 'Network Segment', 'Packet Bin')
# Found good ('Protocol', 'Firewall Logs', 'Scale Packet Length')
# Found good ('Protocol', 'IDS/IPS Alerts', 'Scale Packet Length')
# Time since start for 600 combinations: 14.31 seconds
# Found good ('Protocol', 'Log Source', 'Scale Packet Length')
# Found good ('Protocol', 'Packet Bin', 'Scale Packet Length')
# Found good ('Protocol', 'Scale Packet Length', 'Global Source IP')
# Found good ('Protocol', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Protocol', 'Scale Packet Length', 'Is Proxy')
# Found good ('Packet Type', 'Traffic Type', 'Scale Packet Length')
# Found good ('Packet Type', 'Malware Indicators', 'Scale Packet Length')
# Found good ('Packet Type', 'Alerts/Warnings', 'Scale Packet Length')
# Time since start for 700 combinations: 15.81 seconds
# Found good ('Packet Type', 'Attack Signature', 'Packet Bin')
# Found good ('Packet Type', 'Attack Signature', 'Scale Packet Length')
# Found good ('Packet Type', 'Action Taken', 'Scale Packet Length')
# Found good ('Packet Type', 'Severity Level', 'Scale Packet Length')
# Found good ('Packet Type', 'Network Segment', 'Scale Packet Length')
# Found good ('Packet Type', 'Firewall Logs', 'Scale Packet Length')
# Found good ('Packet Type', 'IDS/IPS Alerts', 'Scale Packet Length')
# Found good ('Packet Type', 'Log Source', 'Scale Packet Length')
# Found good ('Packet Type', 'Packet Bin', 'Scale Packet Length')
# Found good ('Packet Type', 'Scale Packet Length', 'Global Source IP')
# Found good ('Packet Type', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Packet Type', 'Scale Packet Length', 'Is Proxy')
# Time since start for 800 combinations: 17.42 seconds
# Found good ('Traffic Type', 'Malware Indicators', 'Scale Packet Length')
# Found good ('Traffic Type', 'Alerts/Warnings', 'Scale Packet Length')
# Found good ('Traffic Type', 'Attack Signature', 'Scale Packet Length')
# Found good ('Traffic Type', 'Severity Level', 'Packet Bin')
# Time since start for 900 combinations: 18.83 seconds
# Found good ('Traffic Type', 'Firewall Logs', 'Scale Packet Length')
# Found good ('Traffic Type', 'IDS/IPS Alerts', 'Scale Packet Length')
# Found good ('Traffic Type', 'Log Source', 'Scale Packet Length')
# Found good ('Traffic Type', 'Packet Bin', 'Scale Packet Length')
# Found good ('Traffic Type', 'Scale Packet Length', 'Global Source IP')
# Found good ('Traffic Type', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Traffic Type', 'Scale Packet Length', 'Is Proxy')
# Found good ('Malware Indicators', 'Alerts/Warnings', 'Scale Packet Length')
# Found good ('Malware Indicators', 'Attack Signature', 'Scale Packet Length')
# Time since start for 1000 combinations: 20.72 seconds
# Found good ('Malware Indicators', 'Action Taken', 'Scale Packet Length')
# Found good ('Malware Indicators', 'Severity Level', 'Scale Packet Length')
# Found good ('Malware Indicators', 'Network Segment', 'Scale Packet Length')
# Found good ('Malware Indicators', 'Firewall Logs', 'Scale Packet Length')
# Found good ('Malware Indicators', 'IDS/IPS Alerts', 'Scale Packet Length')
# Found good ('Malware Indicators', 'Log Source', 'Scale Packet Length')
# Found good ('Malware Indicators', 'Packet Bin', 'Scale Packet Length')
# Found good ('Malware Indicators', 'Scale Packet Length', 'Global Source IP')
# Found good ('Malware Indicators', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Malware Indicators', 'Scale Packet Length', 'Is Proxy')
# Time since start for 1100 combinations: 22.38 seconds
# Time since start for 1200 combinations: 24.81 seconds
# Found good ('Anomaly Scores', 'Global Source IP', 'Global Destination IP')
# Found good ('Alerts/Warnings', 'Attack Signature', 'Scale Packet Length')
# Found good ('Alerts/Warnings', 'Action Taken', 'Scale Packet Length')
# Found good ('Alerts/Warnings', 'Severity Level', 'Scale Packet Length')
# Found good ('Alerts/Warnings', 'Network Segment', 'Scale Packet Length')
# Found good ('Alerts/Warnings', 'Firewall Logs', 'Scale Packet Length')
# Found good ('Alerts/Warnings', 'IDS/IPS Alerts', 'Scale Packet Length')
# Found good ('Alerts/Warnings', 'Log Source', 'Scale Packet Length')
# Found good ('Alerts/Warnings', 'Packet Bin', 'Scale Packet Length')
# Time since start for 1300 combinations: 26.44 seconds
# Found good ('Alerts/Warnings', 'Scale Packet Length', 'Global Source IP')
# Found good ('Alerts/Warnings', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Alerts/Warnings', 'Scale Packet Length', 'Is Proxy')
# Found good ('Alerts/Warnings', 'Global Source IP', 'Global Destination IP')
# Found good ('Attack Signature', 'Action Taken', 'Scale Packet Length')
# Found good ('Attack Signature', 'Severity Level', 'Scale Packet Length')
# Found good ('Attack Signature', 'Network Segment', 'Scale Packet Length')
# Found good ('Attack Signature', 'Firewall Logs', 'Scale Packet Length')
# Found good ('Attack Signature', 'IDS/IPS Alerts', 'Scale Packet Length')
# Found good ('Attack Signature', 'Log Source', 'Scale Packet Length')
# Found good ('Attack Signature', 'Packet Bin', 'Scale Packet Length')
# Found good ('Attack Signature', 'Scale Packet Length', 'Global Source IP')
# Found good ('Attack Signature', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Attack Signature', 'Scale Packet Length', 'Is Proxy')
# Time since start for 1400 combinations: 28.12 seconds
# Found good ('Action Taken', 'Firewall Logs', 'Scale Packet Length')
# Found good ('Action Taken', 'IDS/IPS Alerts', 'Scale Packet Length')
# Found good ('Action Taken', 'Log Source', 'Scale Packet Length')
# Found good ('Action Taken', 'Packet Bin', 'Scale Packet Length')
# Found good ('Action Taken', 'Scale Packet Length', 'Global Source IP')
# Found good ('Action Taken', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Action Taken', 'Scale Packet Length', 'Is Proxy')
# Time since start for 1500 combinations: 29.85 seconds
# Found good ('Severity Level', 'Firewall Logs', 'Scale Packet Length')
# Found good ('Severity Level', 'IDS/IPS Alerts', 'Scale Packet Length')
# Found good ('Severity Level', 'Log Source', 'Scale Packet Length')
# Found good ('Severity Level', 'Packet Bin', 'Scale Packet Length')
# Found good ('Severity Level', 'Scale Packet Length', 'Global Source IP')
# Found good ('Severity Level', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Severity Level', 'Scale Packet Length', 'Is Proxy')
# Found good ('Network Segment', 'Firewall Logs', 'Scale Packet Length')
# Found good ('Network Segment', 'IDS/IPS Alerts', 'Scale Packet Length')
# Found good ('Network Segment', 'Log Source', 'Scale Packet Length')
# Found good ('Network Segment', 'Packet Bin', 'Scale Packet Length')
# Found good ('Network Segment', 'Scale Packet Length', 'Global Source IP')
# Found good ('Network Segment', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Network Segment', 'Scale Packet Length', 'Is Proxy')
# Time since start for 1600 combinations: 31.74 seconds
# Found good ('Geo-location Data', 'Global Source IP', 'Global Destination IP')
# Found good ('Firewall Logs', 'IDS/IPS Alerts', 'Scale Packet Length')
# Found good ('Firewall Logs', 'Log Source', 'Scale Packet Length')
# Found good ('Firewall Logs', 'Packet Bin', 'Scale Packet Length')
# Found good ('Firewall Logs', 'Scale Packet Length', 'Global Source IP')
# Found good ('Firewall Logs', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Firewall Logs', 'Scale Packet Length', 'Is Proxy')
# Found good ('Firewall Logs', 'Global Source IP', 'Global Destination IP')
# Found good ('IDS/IPS Alerts', 'Log Source', 'Scale Packet Length')
# Found good ('IDS/IPS Alerts', 'Packet Bin', 'Scale Packet Length')
# Time since start for 1700 combinations: 34.07 seconds
# Found good ('IDS/IPS Alerts', 'Scale Packet Length', 'Global Source IP')
# Found good ('IDS/IPS Alerts', 'Scale Packet Length', 'Global Destination IP')
# Found good ('IDS/IPS Alerts', 'Scale Packet Length', 'Is Proxy')
# Found good ('Log Source', 'Packet Bin', 'Scale Packet Length')
# Found good ('Log Source', 'Scale Packet Length', 'Global Source IP')
# Found good ('Log Source', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Log Source', 'Scale Packet Length', 'Is Proxy')
# Found good ('Packet Bin', 'Scale Packet Length', 'Global Source IP')
# Found good ('Packet Bin', 'Scale Packet Length', 'Global Destination IP')
# Found good ('Packet Bin', 'Scale Packet Length', 'Is Proxy')
# Found good ('Scale Packet Length', 'Global Source IP', 'Global Destination IP')
# Found good ('Scale Packet Length', 'Global Source IP', 'Is Proxy')
# Found good ('Scale Packet Length', 'Global Destination IP', 'Is Proxy')

# %%
main_features = combinations_wo_device_df.iloc[:,0:2].value_counts()

# %% [markdown]
# At first look, Packet Type seems to be a good feature to use in combination

# %%
unique_features = main_features.reset_index()[["Feature 1","Feature 2"]].stack().unique()
unique_features
# Out:
# <StringArray>
# [             'Protocol',   'Scale Packet Length',           'Packet Type',
#           'Traffic Type',    'Malware Indicators',       'Alerts/Warnings',
#       'Attack Signature',          'Action Taken',        'Severity Level',
#        'Network Segment',         'Firewall Logs',        'IDS/IPS Alerts',
#             'Log Source',            'Packet Bin',      'Global Source IP',
#         'Anomaly Scores',     'Geo-location Data', 'Global Destination IP']
# Length: 18, dtype: str

# %% [markdown]
# Geo location must be modified to represent city and state <br>

# %%
missing_features = set(cleaned_data.columns) - set(unique_features) - set(["Day", "Month", "Year","Hour","Minute", "Second","IsWeekend","DayOfWeek",
                                                                         "Browser Name", "Browser Version", "Browser Minor","Browser Patch", "Browser Patch Minor",
                                                                         "OS Name", "OS Version", "OS Version Minor", "OS Version Patch", "OS Version Patch Minor",
                                                                         "Device Brand", "Device Model", "Device Type", "Attack Type"])
missing_features
# Out:
# {'Destination Port',
#  'Int Destination IP Address',
#  'Int Source IP Address',
#  'Is Proxy',
#  'Source Port'}

# %% [markdown]
# IP-related features do not appear to provide much information about the attack type when combined with other features

# %% [markdown]
# ### Device Features

# %%
relaunch = ""
while relaunch.lower() not in ["y","n"]:
    relaunch = input("Do you want to relaunch the analysis to find good combinations with device information only? (y/n) ")
if relaunch.lower() == "y":
    data_device = cleaned_data[["Browser Name", "Browser Version", "Browser Minor","Browser Patch", "Browser Patch Minor",
                                    "OS Name", "OS Version", "OS Version Minor", "OS Version Patch", "OS Version Patch Minor",
                                    "Device Brand", "Device Model", "Device Type", "Attack Type"]].copy()
    col_combinations = [col for col in data_device.columns if col != "Attack Type"]
    col_combinations = list(combinations(col_combinations,3))

    nb_rows=data_device.shape[0]
    good_combinations = []
    start_time = time.monotonic()
    for i,combination in enumerate(col_combinations):
        columns = [col for col in combination]+["Attack Type"]
        temp_data = data_device[columns]
        temp_data = temp_data.pivot_table(
            index=combination,  
            columns="Attack Type",
            aggfunc="count",
            fill_value=0
        )
        temp_data["Total"]= temp_data.sum(axis=1)
        percentage_data = temp_data[["DDoS","Malware", "Intrusion"]].div(temp_data["Total"], axis=0)
        percentage_data = percentage_data.max(axis=1) - percentage_data.min(axis=1)
        stats = percentage_data.describe()
        if stats.loc["25%"] > 0.02 and stats.loc["75%"] < 0.99:
            print(f"Found good {combination}")
            output = [feature for feature in combination]
            output.extend([f"%.4f" % stats.loc[x] for x in stats.index])
            good_combinations.append(output)
        if i%100==0 and i!=0:
            print(f"Time since start for {i:d} combinations: {time.monotonic() - start_time:.2f} seconds")
    print(f"Total time: {time.monotonic() - start_time} seconds")
    combinations_wh_device_df = pd.DataFrame(good_combinations, columns=["Feature 1", "Feature 2", "Feature 3", 'count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'])
    combinations_wh_device_df.to_csv(path.joinpath("combinations_wh_device.csv"), index=False)
else:
    combinations_wh_device_df = pd.read_csv(path.joinpath("combinations_wh_device.csv"))
# Out:
# Found good ('Browser Name', 'Browser Version', 'Browser Minor')
# Found good ('Browser Name', 'Browser Version', 'Browser Patch Minor')
# Found good ('Browser Name', 'Browser Version', 'OS Name')
# Found good ('Browser Name', 'Browser Version', 'OS Version Minor')
# Found good ('Browser Name', 'Browser Version', 'OS Version Patch')
# Found good ('Browser Name', 'Browser Version', 'OS Version Patch Minor')
# Found good ('Browser Name', 'Browser Version', 'Device Brand')
# Found good ('Browser Name', 'Browser Version', 'Device Model')
# Found good ('Browser Name', 'Browser Version', 'Device Type')
# Found good ('Browser Name', 'Browser Minor', 'Browser Patch')
# Found good ('Browser Name', 'Browser Minor', 'Browser Patch Minor')
# Found good ('Browser Name', 'Browser Minor', 'OS Name')
# Found good ('Browser Name', 'Browser Minor', 'OS Version')
# Found good ('Browser Name', 'Browser Minor', 'OS Version Minor')
# Found good ('Browser Name', 'Browser Minor', 'OS Version Patch')
# Found good ('Browser Name', 'Browser Minor', 'OS Version Patch Minor')
# Found good ('Browser Name', 'Browser Minor', 'Device Brand')
# Found good ('Browser Name', 'Browser Minor', 'Device Model')
# Found good ('Browser Name', 'Browser Minor', 'Device Type')
# Found good ('Browser Name', 'Browser Patch', 'Browser Patch Minor')
# Found good ('Browser Name', 'Browser Patch', 'OS Name')
# Found good ('Browser Name', 'Browser Patch', 'OS Version Patch Minor')
# Found good ('Browser Name', 'Browser Patch', 'Device Brand')
# Found good ('Browser Name', 'Browser Patch', 'Device Model')
# Found good ('Browser Name', 'Browser Patch', 'Device Type')
# Found good ('Browser Name', 'Browser Patch Minor', 'OS Name')
# Found good ('Browser Name', 'Browser Patch Minor', 'OS Version')
# Found good ('Browser Name', 'Browser Patch Minor', 'OS Version Minor')
# Found good ('Browser Name', 'Browser Patch Minor', 'OS Version Patch')
# Found good ('Browser Name', 'Browser Patch Minor', 'Device Brand')
# Found good ('Browser Name', 'Browser Patch Minor', 'Device Model')
# Found good ('Browser Name', 'Browser Patch Minor', 'Device Type')
# Found good ('Browser Name', 'OS Name', 'OS Version')
# Found good ('Browser Name', 'OS Name', 'OS Version Minor')
# Found good ('Browser Name', 'OS Name', 'OS Version Patch')
# Found good ('Browser Name', 'OS Name', 'OS Version Patch Minor')
# Found good ('Browser Name', 'OS Name', 'Device Brand')
# Found good ('Browser Name', 'OS Name', 'Device Model')
# Found good ('Browser Name', 'OS Name', 'Device Type')
# Found good ('Browser Name', 'OS Version', 'OS Version Minor')
# Found good ('Browser Name', 'OS Version', 'OS Version Patch')
# Found good ('Browser Name', 'OS Version', 'OS Version Patch Minor')
# Found good ('Browser Name', 'OS Version', 'Device Brand')
# Found good ('Browser Name', 'OS Version', 'Device Model')
# Found good ('Browser Name', 'OS Version', 'Device Type')
# Found good ('Browser Name', 'OS Version Minor', 'OS Version Patch')
# Found good ('Browser Name', 'OS Version Minor', 'OS Version Patch Minor')
# Found good ('Browser Name', 'OS Version Minor', 'Device Brand')
# Found good ('Browser Name', 'OS Version Minor', 'Device Model')
# Found good ('Browser Name', 'OS Version Minor', 'Device Type')
# Found good ('Browser Name', 'OS Version Patch', 'OS Version Patch Minor')
# Found good ('Browser Name', 'OS Version Patch', 'Device Brand')
# Found good ('Browser Name', 'OS Version Patch', 'Device Model')
# Found good ('Browser Name', 'OS Version Patch', 'Device Type')
# Found good ('Browser Name', 'OS Version Patch Minor', 'Device Brand')
# Found good ('Browser Name', 'OS Version Patch Minor', 'Device Model')
# Found good ('Browser Name', 'OS Version Patch Minor', 'Device Type')
# Found good ('Browser Name', 'Device Brand', 'Device Model')
# Found good ('Browser Name', 'Device Brand', 'Device Type')
# Found good ('Browser Name', 'Device Model', 'Device Type')
# Found good ('Browser Version', 'Browser Minor', 'Browser Patch Minor')
# Found good ('Browser Version', 'Browser Minor', 'OS Name')
# Found good ('Browser Version', 'Browser Minor', 'OS Version Minor')
# Found good ('Browser Version', 'Browser Minor', 'OS Version Patch')
# Found good ('Browser Version', 'Browser Minor', 'OS Version Patch Minor')
# Found good ('Browser Version', 'Browser Minor', 'Device Brand')
# Found good ('Browser Version', 'Browser Minor', 'Device Model')
# Found good ('Browser Version', 'Browser Minor', 'Device Type')
# Found good ('Browser Version', 'Browser Patch Minor', 'OS Name')
# Found good ('Browser Version', 'Browser Patch Minor', 'OS Version')
# Found good ('Browser Version', 'Browser Patch Minor', 'OS Version Minor')
# Found good ('Browser Version', 'Browser Patch Minor', 'OS Version Patch')
# Found good ('Browser Version', 'Browser Patch Minor', 'OS Version Patch Minor')
# Found good ('Browser Version', 'Browser Patch Minor', 'Device Brand')
# Found good ('Browser Version', 'Browser Patch Minor', 'Device Model')
# Found good ('Browser Version', 'Browser Patch Minor', 'Device Type')
# Found good ('Browser Version', 'OS Name', 'OS Version')
# Found good ('Browser Version', 'OS Name', 'OS Version Minor')
# Found good ('Browser Version', 'OS Name', 'OS Version Patch')
# Found good ('Browser Version', 'OS Name', 'OS Version Patch Minor')
# Found good ('Browser Version', 'OS Name', 'Device Brand')
# Found good ('Browser Version', 'OS Name', 'Device Model')
# Found good ('Browser Version', 'OS Name', 'Device Type')
# Time since start for 100 combinations: 1.52 seconds
# Found good ('Browser Version', 'OS Version', 'OS Version Patch Minor')
# Found good ('Browser Version', 'OS Version', 'Device Brand')
# Found good ('Browser Version', 'OS Version Minor', 'OS Version Patch Minor')
# Found good ('Browser Version', 'OS Version Minor', 'Device Brand')
# Found good ('Browser Version', 'OS Version Minor', 'Device Model')
# Found good ('Browser Version', 'OS Version Minor', 'Device Type')
# Found good ('Browser Version', 'OS Version Patch', 'OS Version Patch Minor')
# Found good ('Browser Version', 'OS Version Patch', 'Device Brand')
# Found good ('Browser Version', 'OS Version Patch Minor', 'Device Brand')
# Found good ('Browser Version', 'OS Version Patch Minor', 'Device Model')
# Found good ('Browser Version', 'OS Version Patch Minor', 'Device Type')
# Found good ('Browser Version', 'Device Brand', 'Device Model')
# Found good ('Browser Version', 'Device Brand', 'Device Type')
# Found good ('Browser Version', 'Device Model', 'Device Type')
# Found good ('Browser Minor', 'Browser Patch', 'Browser Patch Minor')
# Found good ('Browser Minor', 'Browser Patch', 'OS Name')
# Found good ('Browser Minor', 'Browser Patch', 'OS Version Minor')
# Found good ('Browser Minor', 'Browser Patch', 'OS Version Patch')
# Found good ('Browser Minor', 'Browser Patch', 'OS Version Patch Minor')
# Found good ('Browser Minor', 'Browser Patch', 'Device Brand')
# Found good ('Browser Minor', 'Browser Patch', 'Device Model')
# Found good ('Browser Minor', 'Browser Patch', 'Device Type')
# Found good ('Browser Minor', 'Browser Patch Minor', 'OS Name')
# Found good ('Browser Minor', 'Browser Patch Minor', 'OS Version')
# Found good ('Browser Minor', 'Browser Patch Minor', 'OS Version Minor')
# Found good ('Browser Minor', 'Browser Patch Minor', 'OS Version Patch')
# Found good ('Browser Minor', 'Browser Patch Minor', 'OS Version Patch Minor')
# Found good ('Browser Minor', 'Browser Patch Minor', 'Device Brand')
# Found good ('Browser Minor', 'Browser Patch Minor', 'Device Model')
# Found good ('Browser Minor', 'Browser Patch Minor', 'Device Type')
# Found good ('Browser Minor', 'OS Name', 'OS Version')
# Found good ('Browser Minor', 'OS Name', 'OS Version Minor')
# Found good ('Browser Minor', 'OS Name', 'OS Version Patch')
# Found good ('Browser Minor', 'OS Name', 'OS Version Patch Minor')
# Found good ('Browser Minor', 'OS Name', 'Device Brand')
# Found good ('Browser Minor', 'OS Name', 'Device Model')
# Found good ('Browser Minor', 'OS Name', 'Device Type')
# Found good ('Browser Minor', 'OS Version', 'OS Version Minor')
# Found good ('Browser Minor', 'OS Version', 'OS Version Patch')
# Found good ('Browser Minor', 'OS Version', 'OS Version Patch Minor')
# Found good ('Browser Minor', 'OS Version', 'Device Brand')
# Found good ('Browser Minor', 'OS Version', 'Device Model')
# Found good ('Browser Minor', 'OS Version', 'Device Type')
# Found good ('Browser Minor', 'OS Version Minor', 'OS Version Patch')
# Found good ('Browser Minor', 'OS Version Minor', 'OS Version Patch Minor')
# Found good ('Browser Minor', 'OS Version Minor', 'Device Brand')
# Found good ('Browser Minor', 'OS Version Minor', 'Device Model')
# Found good ('Browser Minor', 'OS Version Minor', 'Device Type')
# Found good ('Browser Minor', 'OS Version Patch', 'OS Version Patch Minor')
# Found good ('Browser Minor', 'OS Version Patch', 'Device Brand')
# Found good ('Browser Minor', 'OS Version Patch', 'Device Model')
# Found good ('Browser Minor', 'OS Version Patch', 'Device Type')
# Found good ('Browser Minor', 'OS Version Patch Minor', 'Device Brand')
# Found good ('Browser Minor', 'OS Version Patch Minor', 'Device Model')
# Found good ('Browser Minor', 'OS Version Patch Minor', 'Device Type')
# Found good ('Browser Minor', 'Device Brand', 'Device Model')
# Found good ('Browser Minor', 'Device Brand', 'Device Type')
# Found good ('Browser Minor', 'Device Model', 'Device Type')
# Found good ('Browser Patch', 'Browser Patch Minor', 'OS Name')
# Found good ('Browser Patch', 'Browser Patch Minor', 'OS Version Patch')
# Found good ('Browser Patch', 'Browser Patch Minor', 'OS Version Patch Minor')
# Found good ('Browser Patch', 'Browser Patch Minor', 'Device Brand')
# Found good ('Browser Patch', 'Browser Patch Minor', 'Device Model')
# Found good ('Browser Patch', 'Browser Patch Minor', 'Device Type')
# Found good ('Browser Patch', 'OS Name', 'OS Version Patch Minor')
# Found good ('Browser Patch', 'OS Name', 'Device Brand')
# Found good ('Browser Patch', 'OS Name', 'Device Model')
# Found good ('Browser Patch', 'OS Name', 'Device Type')
# Found good ('Browser Patch', 'OS Version Patch', 'OS Version Patch Minor')
# Found good ('Browser Patch', 'OS Version Patch Minor', 'Device Brand')
# Found good ('Browser Patch', 'OS Version Patch Minor', 'Device Model')
# Found good ('Browser Patch', 'OS Version Patch Minor', 'Device Type')
# Found good ('Browser Patch', 'Device Brand', 'Device Model')
# Found good ('Browser Patch', 'Device Brand', 'Device Type')
# Time since start for 200 combinations: 3.05 seconds
# Found good ('Browser Patch', 'Device Model', 'Device Type')
# Found good ('Browser Patch Minor', 'OS Name', 'OS Version')
# Found good ('Browser Patch Minor', 'OS Name', 'OS Version Minor')
# Found good ('Browser Patch Minor', 'OS Name', 'OS Version Patch')
# Found good ('Browser Patch Minor', 'OS Version', 'OS Version Minor')
# Found good ('Browser Patch Minor', 'OS Version', 'OS Version Patch')
# Found good ('Browser Patch Minor', 'OS Version', 'OS Version Patch Minor')
# Found good ('Browser Patch Minor', 'OS Version', 'Device Brand')
# Found good ('Browser Patch Minor', 'OS Version', 'Device Model')
# Found good ('Browser Patch Minor', 'OS Version', 'Device Type')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'OS Version Patch')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'OS Version Patch Minor')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'Device Brand')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'Device Model')
# Found good ('Browser Patch Minor', 'OS Version Minor', 'Device Type')
# Found good ('Browser Patch Minor', 'OS Version Patch', 'OS Version Patch Minor')
# Found good ('Browser Patch Minor', 'OS Version Patch', 'Device Brand')
# Found good ('Browser Patch Minor', 'OS Version Patch', 'Device Model')
# Found good ('Browser Patch Minor', 'OS Version Patch', 'Device Type')
# Found good ('OS Name', 'OS Version', 'OS Version Minor')
# Found good ('OS Name', 'OS Version', 'OS Version Patch')
# Found good ('OS Name', 'OS Version', 'OS Version Patch Minor')
# Found good ('OS Name', 'OS Version', 'Device Brand')
# Found good ('OS Name', 'OS Version', 'Device Model')
# Found good ('OS Name', 'OS Version', 'Device Type')
# Found good ('OS Name', 'OS Version Minor', 'OS Version Patch')
# Found good ('OS Name', 'OS Version Minor', 'Device Model')
# Found good ('OS Name', 'OS Version Minor', 'Device Type')
# Found good ('OS Name', 'OS Version Patch', 'OS Version Patch Minor')
# Found good ('OS Name', 'OS Version Patch', 'Device Brand')
# Found good ('OS Name', 'OS Version Patch', 'Device Model')
# Found good ('OS Name', 'OS Version Patch', 'Device Type')
# Found good ('OS Version', 'OS Version Minor', 'OS Version Patch')
# Found good ('OS Version', 'OS Version Minor', 'OS Version Patch Minor')
# Found good ('OS Version', 'OS Version Minor', 'Device Brand')
# Found good ('OS Version', 'OS Version Minor', 'Device Model')
# Found good ('OS Version', 'OS Version Minor', 'Device Type')
# Found good ('OS Version', 'OS Version Patch', 'OS Version Patch Minor')
# Found good ('OS Version', 'OS Version Patch', 'Device Brand')
# Found good ('OS Version', 'OS Version Patch', 'Device Model')
# Found good ('OS Version', 'OS Version Patch', 'Device Type')
# Found good ('OS Version', 'OS Version Patch Minor', 'Device Brand')
# Found good ('OS Version', 'OS Version Patch Minor', 'Device Model')
# Found good ('OS Version', 'OS Version Patch Minor', 'Device Type')
# Found good ('OS Version', 'Device Brand', 'Device Model')
# Found good ('OS Version', 'Device Brand', 'Device Type')
# Found good ('OS Version', 'Device Model', 'Device Type')
# Found good ('OS Version Minor', 'OS Version Patch', 'OS Version Patch Minor')
# Found good ('OS Version Minor', 'OS Version Patch', 'Device Brand')
# Found good ('OS Version Minor', 'OS Version Patch', 'Device Model')
# Found good ('OS Version Minor', 'OS Version Patch', 'Device Type')
# Found good ('OS Version Minor', 'OS Version Patch Minor', 'Device Brand')
# Found good ('OS Version Minor', 'OS Version Patch Minor', 'Device Model')
# Found good ('OS Version Minor', 'OS Version Patch Minor', 'Device Type')
# Found good ('OS Version Minor', 'Device Brand', 'Device Model')
# Found good ('OS Version Minor', 'Device Brand', 'Device Type')
# Found good ('OS Version Minor', 'Device Model', 'Device Type')
# Found good ('OS Version Patch', 'OS Version Patch Minor', 'Device Brand')
# Found good ('OS Version Patch', 'OS Version Patch Minor', 'Device Model')
# Found good ('OS Version Patch', 'OS Version Patch Minor', 'Device Type')
# Found good ('OS Version Patch', 'Device Brand', 'Device Model')
# Found good ('OS Version Patch', 'Device Brand', 'Device Type')
# Found good ('OS Version Patch', 'Device Model', 'Device Type')

# %%
main_features = combinations_wh_device_df.iloc[:,0:2].value_counts()

# %% [markdown]
# Browser seems to be important whereas device doesn't
